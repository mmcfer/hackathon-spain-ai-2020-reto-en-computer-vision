# %% [markdown]
# Importació de llibreries

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-c3e9a6c7-22b4-300f-5cc3-995897cf3b47)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torchsummary import summary
from torch import Tensor
from torch.jit.annotations import List, Tuple


import torchvision.transforms.functional as TF


import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler

from torchvision import transforms
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

import matplotlib.pyplot as plt
import random
import argparse
import os
import sys
import numpy as np
import numbers
from collections.abc import Sequence

from math import exp
import numpy
import math
import scipy.signal
import scipy.ndimage
import datetime
import time

# %% [markdown]
# Definició Classes

# %%
# class to extract features for the input image in a different image space like VGG19, AlexNet, DenseNet, etc.
class FeatureExtractor(nn.Module):
    
    def __init__(self, cnn, feature_layer=11):
        super(FeatureExtractor, self).__init__()
        self.features = nn.Sequential(*list(cnn.features.children())[:(feature_layer+1)])

    def forward(self, x):
        return self.features(x)

def save_img(x, dir):
    x = x.cpu().numpy().astype(np.float32)
    x_min = np.min(x)
    x_max = np.max(x)
    x = (x - x_min) / (x_max - x_min)
    x = Image.fromarray(x * 255)
    if x.mode != 'RGB':
        x = x.convert('RGB')
    x.save(dir)


def calc_mean_std(feat, eps=1e-5):
    # eps is a small value added to the variance to avoid divide-by-zero.
    size = feat.size()
    assert (len(size) == 4)
    N, C = size[:2]
    feat_var = feat.view(N, C, -1).var(dim=2) + eps
    feat_std = feat_var.sqrt().view(N, C, 1, 1)
    feat_mean = feat.view(N, C, -1).mean(dim=2).view(N, C, 1, 1)
    return feat_mean, feat_std


class DAC(nn.Module):
    def __init__(self, n_channels):
        super(DAC, self).__init__()

        self.mean = nn.Sequential(
            nn.Conv2d(n_channels, n_channels // 16, 1, 1, 0, 1, 1, False),
            # nn.BatchNorm2d(n_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(n_channels // 16, n_channels, 1, 1, 0, 1, 1, False),
            # nn.BatchNorm2d(n_channels),
        )
        self.std = nn.Sequential(
            nn.Conv2d(n_channels, n_channels // 16, 1, 1, 0, 1, 1, False),
            # nn.BatchNorm2d(n_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(n_channels // 16, n_channels, 1, 1, 0, 1, 1, False),
            # nn.BatchNorm2d(n_channels),
        )

    def forward(self, observed_feat, referred_feat):
        assert (observed_feat.size()[:2] == referred_feat.size()[:2])
        size = observed_feat.size()
        referred_mean, referred_std = calc_mean_std(referred_feat)
        observed_mean, observed_std = calc_mean_std(observed_feat)

        normalized_feat = (observed_feat - observed_mean.expand(
            size)) / observed_std.expand(size)
        referred_mean = self.mean(referred_mean)
        referred_std = self.std(referred_std)
        output = normalized_feat * referred_std.expand(size) + referred_mean.expand(size)
        return output


class MSHF(nn.Module):
    def __init__(self, n_channels, kernel=3):
        super(MSHF, self).__init__()

        pad = int((kernel - 1) / 2)

        self.grad_xx = nn.Conv2d(in_channels=n_channels, out_channels=n_channels, kernel_size=3, stride=1, padding=pad,
                                 dilation=pad, groups=n_channels, bias=True)
        self.grad_yy = nn.Conv2d(in_channels=n_channels, out_channels=n_channels, kernel_size=3, stride=1, padding=pad,
                                 dilation=pad, groups=n_channels, bias=True)
        self.grad_xy = nn.Conv2d(in_channels=n_channels, out_channels=n_channels, kernel_size=3, stride=1, padding=pad,
                                 dilation=pad, groups=n_channels, bias=True)

        for m in self.modules():
            if m == self.grad_xx:
                m.weight.data.zero_()
                m.weight.data[:, :, 1, 0] = 1
                m.weight.data[:, :, 1, 1] = -2
                m.weight.data[:, :, 1, -1] = 1
            elif m == self.grad_yy:
                m.weight.data.zero_()
                m.weight.data[:, :, 0, 1] = 1
                m.weight.data[:, :, 1, 1] = -2
                m.weight.data[:, :, -1, 1] = 1
            elif m == self.grad_xy:
                m.weight.data.zero_()
                m.weight.data[:, :, 0, 0] = 1
                m.weight.data[:, :, 0, -1] = -1
                m.weight.data[:, :, -1, 0] = -1
                m.weight.data[:, :, -1, -1] = 1

        # # Freeze the MeanShift layer
        # for params in self.parameters():
        #     params.requires_grad = False

    def forward(self, x):
        fxx = self.grad_xx(x)
        fyy = self.grad_yy(x)
        fxy = self.grad_xy(x)
        hessian = ((fxx + fyy) + ((fxx - fyy) ** 2 + 4 * (fxy ** 2)) ** 0.5) / 2
        return hessian


class rcab_block(nn.Module):
    def __init__(self, n_channels, kernel, bias=False, activation=nn.ReLU(inplace=True)):
        super(rcab_block, self).__init__()

        block = []

        block.append(nn.Conv2d(in_channels=n_channels, out_channels=n_channels, kernel_size=kernel, padding=1, bias=bias))
        block.append(activation)
        block.append(nn.Conv2d(in_channels=n_channels, out_channels=n_channels, kernel_size=kernel, padding=1, bias=bias))

        self.block = nn.Sequential(*block)

        self.calayer = nn.Sequential(
            nn.Conv2d(n_channels, n_channels // 16, 1, padding=0, bias=True),
            nn.ReLU(inplace=True),
            nn.Conv2d(n_channels // 16, n_channels, 1, padding=0, bias=True),
            nn.Sigmoid()
        )

    def forward(self, x):
        residue = self.block(x)
        chnlatt = F.adaptive_avg_pool2d(residue, 1)
        chnlatt = self.calayer(chnlatt)
        output = x + residue * chnlatt

        return output


class DiEnDec(nn.Module):
    def __init__(self, n_channels, act=nn.ReLU(inplace=True)):
        super(DiEnDec, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(n_channels, n_channels * 2, kernel_size=3, padding=1, dilation=1, bias=True),
            act,
            nn.Conv2d(n_channels * 2, n_channels * 4, kernel_size=3, padding=2, dilation=2, bias=True),
            act,
            nn.Conv2d(n_channels * 4, n_channels * 8, kernel_size=3, padding=4, dilation=4, bias=True),
            act,
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(n_channels * 8, n_channels * 4, kernel_size=3, padding=4, dilation=4, bias=True),
            act,
            nn.ConvTranspose2d(n_channels * 4, n_channels * 2, kernel_size=3, padding=2, dilation=2, bias=True),
            act,
            nn.ConvTranspose2d(n_channels * 2, n_channels, kernel_size=3, padding=1, dilation=1, bias=True),
            act,
        )
        self.gate = nn.Conv2d(in_channels=n_channels, out_channels=1, kernel_size=1)

    def forward(self, x):
        output = self.gate(self.decoder(self.encoder(x)))
        return output


class SingleModule(nn.Module):
    def __init__(self, n_channels, n_blocks, act, attention):
        super(SingleModule, self).__init__()
        res_blocks = [rcab_block(n_channels=n_channels, kernel=3, activation=act) for _ in range(n_blocks)]
        self.body_block = nn.Sequential(*res_blocks)
        self.attention = attention
        if attention:
            self.coder = nn.Sequential(DiEnDec(3, act))
            self.dac = nn.Sequential(DAC(n_channels))
            self.hessian3 = nn.Sequential(MSHF(n_channels, kernel=3))
            self.hessian5 = nn.Sequential(MSHF(n_channels, kernel=5))
            self.hessian7 = nn.Sequential(MSHF(n_channels, kernel=7))

    def forward(self, x):
        sz = x.size()
        resin = self.body_block(x)

        if self.attention:
            hessian3 = self.hessian3(resin)
            hessian5 = self.hessian5(resin)
            hessian7 = self.hessian7(resin)
            hessian = torch.cat((torch.mean(hessian3, dim=1, keepdim=True),
                                 torch.mean(hessian5, dim=1, keepdim=True),
                                 torch.mean(hessian7, dim=1, keepdim=True))
                                , 1)
            hessian = self.coder(hessian)
            attention = torch.sigmoid(self.dac[0](hessian.expand(sz), x))
            resout = resin * attention
        else:
            resout = resin

        output = resout + x

        return output


class Generator(nn.Module):
    def __init__(self, n_channels, n_blocks, n_modules, act=nn.ReLU(True), attention=True, scale=(2, 3, 4)):
        super(Generator, self).__init__()
        self.n_modules = n_modules
        self.input = nn.Conv2d(in_channels=3, out_channels=n_channels, kernel_size=3, stride=1, padding=1, bias=True)
        if n_modules == 1:
            self.body = nn.Sequential(SingleModule(n_channels, n_blocks, act, attention))
        else:
            self.body = nn.Sequential(*[SingleModule(n_channels, n_blocks, act, attention) for _ in range(n_modules)])

        self.tail = nn.Conv2d(n_channels, n_channels, 3, 1, 1, bias=True)

        self.upscale = nn.ModuleList([UpScale(n_channels=n_channels, scale=s, act=False) for s in scale])

        self.output = nn.Conv2d(in_channels=n_channels, out_channels=3, kernel_size=3, stride=1, padding=1, bias=True)

    def forward(self, x):

        body_input = self.input(x)
        body_output = self.body(body_input)
        if self.n_modules == 1:
            sr_high = self.upscale[0](body_output)
        else:
            sr_high = self.upscale[0](self.tail(body_output) + body_input)
        results = self.output(sr_high)

        return results


class UpScale(nn.Sequential):
    def __init__(self, n_channels, scale, bn=False, act=nn.ReLU(inplace=True), bias=False):
        layers = []
        if (scale & (scale - 1)) == 0:
            for _ in range(int(math.log(scale, 2))):
                layers.append(nn.Conv2d(in_channels=n_channels, out_channels=4 * n_channels, kernel_size=3, stride=1,
                                        padding=1, bias=bias))
                layers.append(nn.PixelShuffle(2))
                if bn: layers.append(nn.BatchNorm2d(n_channels))
                if act: layers.append(act)
        elif scale == 3:
            layers.append(nn.Conv2d(in_channels=n_channels, out_channels=9 * n_channels, kernel_size=3, stride=1,
                                    padding=1, bias=bias))
            layers.append(nn.PixelShuffle(3))
            if bn: layers.append(nn.BatchNorm2d(n_channels))
            if act: layers.append(act)
        else:
            raise NotImplementedError

        super(UpScale, self).__init__(*layers)

# discriminator class definition    
class Discriminator(nn.Module):
    
    def __init__(self):
        super(Discriminator, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, stride=1, padding=1)
      
        self.conv2 = nn.utils.spectral_norm(nn.Conv2d(64, 64, 3, stride=2, padding=1))
        self.conv3 = nn.utils.spectral_norm(nn.Conv2d(64, 128, 3, stride=1, padding=1))
        self.conv4 = nn.utils.spectral_norm(nn.Conv2d(128, 128, 3, stride=2, padding=1))
        self.conv5 = nn.utils.spectral_norm(nn.Conv2d(128, 256, 3, stride=1, padding=1))
        self.conv6 = nn.utils.spectral_norm(nn.Conv2d(256, 256, 3, stride=2, padding=1))
        self.conv7 = nn.utils.spectral_norm(nn.Conv2d(256, 512, 3, stride=1, padding=1))
        self.conv8 = nn.utils.spectral_norm(nn.Conv2d(512, 512, 3, stride=2, padding=1))

        self.conv9 = nn.Conv2d(512, 1, 1, stride=1, padding=1)
        
        self.leakyrelu = nn.LeakyReLU(0.2, inplace=True)
        
    def forward(self, x):
        x = self.leakyrelu(self.conv1(x))

        x = self.leakyrelu(self.conv2(x))
        x = self.leakyrelu(self.conv3(x))
        x = self.leakyrelu(self.conv4(x))
        x = self.leakyrelu(self.conv5(x))
        x = self.leakyrelu(self.conv6(x))
        x = self.leakyrelu(self.conv7(x))
        x = self.leakyrelu(self.conv8(x))

        x = self.conv9(x)
        return F.avg_pool2d(x, x.size()[2:])#.view(x.size()[0], -1), F.avg_pool2d(x, x.size()[2:])

# class to visualize results    
class Visualizer:
    
    def __init__(self, show_step=100, image_size=30):
        self.transform = transforms.Compose([transforms.Normalize((-1, -1, -1), (2, 2, 2)),
                                            transforms.ToPILImage(),
                                            transforms.Resize(image_size)])

        self.show_step = show_step
        self.step = 0

        self.figure, (self.lr_plot, self.hr_plot, self.fake_plot) = plt.subplots(1,3)
        self.figure.show()

        self.lr_image_ph = None
        self.hr_image_ph = None
        self.fake_hr_image_ph = None

    def show(self, inputsG, inputsD_real, inputsD_fake):

        self.step += 1
        
        if self.step == self.show_step:
            i = random.randint(0, inputsG.size(0) -1)

            lr_image = self.transform(inputsG[i])
            hr_image = self.transform(inputsD_real[i])
            fake_hr_image = self.transform(inputsD_fake[i])

            if self.lr_image_ph is None:
                self.lr_image_ph = self.lr_plot.imshow(lr_image)
                self.hr_image_ph = self.hr_plot.imshow(hr_image)
                self.fake_hr_image_ph = self.fake_plot.imshow(fake_hr_image)
            else:
                self.lr_image_ph.set_data(lr_image)
                self.hr_image_ph.set_data(hr_image)
                self.fake_hr_image_ph.set_data(fake_hr_image)

            self.figure.canvas.draw()
            plt.pause(0.001)
            
            self.step = 0
            self.figure, (self.lr_plot, self.hr_plot, self.fake_plot) = plt.subplots(1,3)
            self.lr_image_ph = None
            self.hr_image_ph = None
            self.fake_hr_image_ph = None

# %% [markdown]
# Mètriques

# %%
# Image quality metrics

# 1. SSIM - Structural Similarity Metric
from math import exp
  
# from piqa import ssim

# class SSIM(ssim.SSIM):
#     def forward(self, x, y):
#         return 1. - super().forward(x, y)

def gaussian(window_size, sigma):
    gauss = torch.Tensor([exp(-(x - window_size//2)**2/float(2*sigma**2)) for x in range(window_size)])
    return gauss/gauss.sum()

def create_window(window_size, channel):
    _1D_window = gaussian(window_size, 1.5).unsqueeze(1)
    _2D_window = _1D_window.mm(_1D_window.t()).float().unsqueeze(0).unsqueeze(0)
    window = Variable(_2D_window.expand(channel, 1, window_size, window_size).contiguous())
    return window

def _ssim(img1, img2, window, window_size, channel, size_average = True):
    mu1 = F.conv2d(img1, window, padding = window_size//2, groups = channel)
    mu2 = F.conv2d(img2, window, padding = window_size//2, groups = channel)

    mu1_sq = mu1.pow(2)
    mu2_sq = mu2.pow(2)
    mu1_mu2 = mu1*mu2

    sigma1_sq = F.conv2d(img1*img1, window, padding = window_size//2, groups = channel) - mu1_sq
    sigma2_sq = F.conv2d(img2*img2, window, padding = window_size//2, groups = channel) - mu2_sq
    sigma12 = F.conv2d(img1*img2, window, padding = window_size//2, groups = channel) - mu1_mu2

    C1 = 0.01**2
    C2 = 0.03**2

    ssim_map = ((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*(sigma1_sq + sigma2_sq + C2))

    if size_average:
        return ssim_map.mean()
    else:
        return ssim_map.mean(1).mean(1).mean(1)

class SSIM(torch.nn.Module):
    def __init__(self, window_size = 11, size_average = True):
        super(SSIM, self).__init__()
        self.window_size = window_size
        self.size_average = size_average
        self.channel = 1
        self.window = create_window(window_size, self.channel)

    def forward(self, img1, img2):
        (_, channel, _, _) = img1.size()
        
        if channel == self.channel and self.window.data.type() == img1.data.type():
            window = self.window
        else:
            window = create_window(self.window_size, channel)
            
            if img1.is_cuda:
                window = window.cuda(img1.get_device())
            window = window.type_as(img1)
            
            self.window = window
            self.channel = channel


        return _ssim(img1, img2, window, self.window_size, channel, self.size_average)

def ssim(img1, img2, window_size = 11, size_average = True):
    (_, channel, _, _) = img1.size()
    window = create_window(window_size, channel)
    
    if img1.is_cuda:
        window = window.cuda(img1.get_device())
    window = window.type_as(img1)
    
    return _ssim(img1, img2, window, window_size, channel, size_average)


# 2. VIFP - Visual Information Fidelity Measure 
def vifp_measure(ref, dist):
  
    ref = ref.cpu().detach().numpy()
    dist = dist.cpu().detach().numpy()
    sigma_nsq=2
    eps = 1e-10

    num = 0.0
    den = 0.0
    for scale in range(1, 5):
       
        N = 2**(4-scale+1) + 1
        sd = N/5.0

        if (scale > 1):
            ref = scipy.ndimage.gaussian_filter(ref, sd)
            dist = scipy.ndimage.gaussian_filter(dist, sd)
            ref = ref[::2, ::2]
            dist = dist[::2, ::2]
                
        mu1 = scipy.ndimage.gaussian_filter(ref, sd)
        mu2 = scipy.ndimage.gaussian_filter(dist, sd)
        mu1_sq = mu1 * mu1
        mu2_sq = mu2 * mu2
        mu1_mu2 = mu1 * mu2
        sigma1_sq = scipy.ndimage.gaussian_filter(ref * ref, sd) - mu1_sq
        sigma2_sq = scipy.ndimage.gaussian_filter(dist * dist, sd) - mu2_sq
        sigma12 = scipy.ndimage.gaussian_filter(ref * dist, sd) - mu1_mu2
        
        sigma1_sq[sigma1_sq<0] = 0
        sigma2_sq[sigma2_sq<0] = 0
        
        g = sigma12 / (sigma1_sq + eps)
        sv_sq = sigma2_sq - g * sigma12
        
        g[sigma1_sq<eps] = 0
        sv_sq[sigma1_sq<eps] = sigma2_sq[sigma1_sq<eps]
        sigma1_sq[sigma1_sq<eps] = 0
        
        g[sigma2_sq<eps] = 0
        sv_sq[sigma2_sq<eps] = 0
        
        sv_sq[g<0] = sigma2_sq[g<0]
        g[g<0] = 0
        sv_sq[sv_sq<=eps] = eps
        
        num += numpy.sum(numpy.log10(1 + g * g * sigma1_sq / (sv_sq + sigma_nsq)))
        den += numpy.sum(numpy.log10(1 + sigma1_sq / sigma_nsq))
        
    vifp = num/den


    return vifp

# %%
import torchvision.transforms.functional_pil as F_pil
import torchvision.transforms.functional_tensor as F_t

from torchvision.transforms.functional import crop, center_crop


def sixtenn_crop_custom(img: Tensor, size: List[int], border: List[int]) -> Tuple[Tensor, Tensor, Tensor, Tensor, Tensor]:

    if isinstance(size, numbers.Number):
        size = (int(size), int(size))
    elif isinstance(size, (tuple, list)) and len(size) == 1:
        size = (size[0], size[0])

    if len(size) != 2:
        raise ValueError("Please provide only two dimensions (h, w) for size.")

    if isinstance(border, numbers.Number):
        border = (int(border), int(border))
    elif isinstance(border, (tuple, list)) and len(border) == 1:
        border = (border[0], border[0])

    if len(border) != 2:
        raise ValueError("Please provide only two dimensions (h, w) for size.")

    image_width, image_height = _get_image_size(img)
    crop_height, crop_width = size
    border_height, border_width = border

    if crop_width > image_width or crop_height > image_height:
        msg = "Requested crop size {} is bigger than input size {}"
        raise ValueError(msg.format(size, (image_height, image_width)))

    tl1 = crop(img, 0, 0, crop_height + border_height, crop_width + border_width)
    tl2 = crop(img, 0, image_width - crop_width*3 - border_width/2, crop_height + border_height, crop_width + border_width)
    tl3 = crop(img, image_height - crop_height*3 - border_height/2, 0, crop_height + border_height, crop_width + border_width)
    tl4 = crop(img, image_height - crop_height*3 - border_height/2, image_width - crop_width*3 - border_width/2, crop_height + border_height, crop_width + border_width)

    tr1 = crop(img, 0, image_width - crop_width*2 - border_width/2, crop_height + border_height, crop_width + border_width )
    tr2 = crop(img, 0, image_width - crop_width - border_width, crop_height + border_height, crop_width + border_width)
    tr3 = crop(img, image_height - crop_height*3 - border_height/2, image_width - crop_width*2 - border_width/2, crop_height + border_height, crop_width + border_width)
    tr4 = crop(img, image_height - crop_height*3 - border_height/2, image_width - crop_width - border_width, crop_height + border_height, crop_width + border_width)

    bl1 = crop(img, image_height - crop_height*2 - border_height/2, 0, crop_height + border_height, crop_width + border_width)
    bl2 = crop(img, image_height - crop_height*2 - border_height/2, image_width - crop_width*3 - border_width/2, crop_height + border_height, crop_width + border_width)
    bl3 = crop(img, image_height - crop_height - border_height, 0, crop_height + border_height, crop_width + border_width)
    bl4 = crop(img, image_height - crop_height - border_height, image_width - crop_width*3 - border_width/2, crop_height + border_height, crop_width + border_width)

    br1 = crop(img, image_height - crop_height*2 - border_height/2, image_width - crop_width*2 - border_width/2, crop_height + border_height, crop_width + border_width)
    br2 = crop(img, image_height - crop_height*2 - border_height/2, image_width - crop_width - border_width, crop_height + border_height, crop_width + border_width)
    br3 = crop(img, image_height - crop_height - border_height, image_width - crop_width*2 - border_width/2, crop_height + border_height, crop_width + border_width)
    br4 = crop(img, image_height - crop_height - border_height, image_width - crop_width - border_width, crop_height + border_height, crop_width + border_width)

    # center = center_crop(img, [crop_height + border_height, crop_width + crop_width])

    return tl1,tl2,tl3,tl4, tr1,tr2,tr3,tr4, bl1,bl2,bl3,bl4, br1,br2,br3,br4 

class Sixteen_custom(torch.nn.Module):


    def __init__(self, size, border):
        super().__init__()
        self.size = _setup_size(size, error_msg="Please provide only two dimensions (h, w) for size.")
        self.border = _setup_size(border, error_msg="Please provide only two dimensions (h, w) for size.")

    def forward(self, img):
        """
        Args:
            img (PIL Image or Tensor): Image to be cropped.

        Returns:
            tuple of 5 images. Image can be PIL Image or Tensor
        """
        return sixtenn_crop_custom(img, self.size,self.border)


    def __repr__(self):
        return self.__class__.__name__ + '(size={0})'.format(self.size)



def _setup_size(size, error_msg):
    if isinstance(size, numbers.Number):
        return int(size), int(size)

    if isinstance(size, Sequence) and len(size) == 1:
        return size[0], size[0]

    if len(size) != 2:
        raise ValueError(error_msg)

    return size

def _get_image_size(img: Tensor) -> List[int]:
    """Returns image sizea as (w, h)
    """
    if isinstance(img, torch.Tensor):
        return F_t._get_image_size(img)

    return F_pil._get_image_size(img)

# %% [markdown]
# Prova Carrega Imàgens

# %%
from os import listdir
from os.path import isfile, join
from PIL import Image
from IPython.display import display

dataset = 'TrainingSet'
dataroot = './drive/MyDrive/Datasets/SuperResolution/TrainingSet'
subfolder="Set/600px"

dataroot_real = './drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real'

# onlyfiles = [f for f in listdir(join(dataroot,subfolder)) if isfile(join(join(dataroot,subfolder), f))]
# pil_im = Image.open(join(join(dataroot,subfolder),onlyfiles[0]))

# # onlyfiles = [f for f in listdir(dataroot) if isfile(join(dataroot, f))]
# # pil_im = Image.open(join(dataroot,onlyfiles[0]))


# display(pil_im)
# print(len(onlyfiles))
# print(pil_im.size)

# %% [markdown]
# Entrenament - Carrega Dades

# %%
"""
Training the model

"""


workers = 1
batchSize = 1
# imageSize_w = 150
# imageSize_h = 300
imageSize_w = 150
imageSize_h = 150
border= 50
upSampling = 4
factor=4
nEpochs = 15
cuda = True

generatorWeights = 'generator_final_ep3_13.5578.pth'
discriminatorWeights = 'discriminator_final_ep3_13.5578.pth'
experiment='20210329-161145_16parts_defian_mse/models'

out = './drive/MyDrive/checkpoints'

try:
    os.makedirs(out)
except OSError:
    pass

if torch.cuda.is_available() and not cuda:
    print("WARNING: You have a CUDA device! You should probably set the variable 'cuda=True'")

#transform the data    
# transform = transforms.Compose([transforms.Resize(imageSize),
#                                 transforms.ToTensor()])

normalize = transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))

# transform = transforms.Compose([transforms.Resize(imageSize*2),FiveCrop_custom(imageSize,border),transforms.Lambda(lambda crops: torch.stack([normalize(transforms.ToTensor()(crop)) for crop in crops[0:4]]))])

transform = transforms.Compose([Sixteen_custom([imageSize_h,imageSize_w],border),transforms.Lambda(lambda crops: torch.stack([normalize(transforms.ToTensor()(crop)) for crop in crops]))])


# transforms.Lambda(lambda crops: torch.stack([(transforms.ToTensor()(crop)) for crop in crops]))

# transform_real = transforms.Compose([transforms.Resize(imageSize*upSampling),
#                                 transforms.ToTensor()])

# transform_real = transforms.Compose([transforms.Resize(imageSize*2*upSampling),FiveCrop_custom(imageSize*upSampling,border*upSampling),transforms.Lambda(lambda crops: torch.stack([normalize(transforms.ToTensor()(crop)) for crop in crops[0:4]]))])

# transform_real = transforms.Compose([transforms.Resize(2400,torchvision.transforms.InterpolationMode.BICUBIC),Sixteen_custom([imageSize_h*upSampling,imageSize_w*upSampling],border*upSampling),transforms.Lambda(lambda crops: torch.stack([normalize(transforms.ToTensor()(crop)) for crop in crops]))])
transform_real = transforms.Compose([Sixteen_custom([imageSize_h*upSampling,imageSize_w*upSampling],border*upSampling),transforms.Lambda(lambda crops: torch.stack([normalize(transforms.ToTensor()(crop)) for crop in crops]))])


# transform = transforms.Compose([transforms.ToTensor()])

# transform_real = transforms.Compose([transforms.ToTensor()])



transform_to_save = transforms.Compose([transforms.Normalize((-1, -1, -1), (2, 2, 2)),
                                            transforms.ToPILImage()])

# transform = transforms.Compose([transforms.ToTensor()])


# load training data
if dataset == 'TrainingSet':
    dataset_train = datasets.ImageFolder(root=dataroot, transform=transform)
    dataset_train_real = datasets.ImageFolder(root=dataroot_real, transform=transform_real)
    print("Dataset")
assert dataset_train

dataloader_train = torch.utils.data.DataLoader(dataset_train, batch_size=batchSize,
                                         shuffle=False, num_workers=int(workers))

dataloader_train_real = torch.utils.data.DataLoader(dataset_train_real, batch_size=batchSize,
                                         shuffle=False, num_workers=int(workers))


print(dataset_train[0][0].shape)
print(dataset_train_real[0][0].shape)
# Out:
# Dataset
# torch.Size([16, 3, 200, 200])
# torch.Size([16, 3, 800, 800])

# %%
# initialize generator
# generator = Generator(args.n_channels, args.n_blocks, args.n_modules, args.activation,
#                       attention=args.attention, scale=[args.scale])


# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# generator= Generator(32, 10, 5, nn.ReLU(True),attention=True, scale=[upSampling ])
generator= Generator(64, 20, 10, nn.ReLU(True),attention=True, scale=[upSampling])

# generator.to(device)

# Optional DataParallel, not needed for single GPU usage
# generator1 = torch.nn.DataParallel(generator, device_ids=[0]).to(device)
# Or, using default 'device_ids=None'
# generator1= torch.nn.DataParallel(generator).to(device)

if generatorWeights != '':
    generator.load_state_dict(torch.load(join(out,experiment,generatorWeights)))
    # cpk = torch.load((join(out,experiment,generatorWeights)), map_location={'cuda:1': 'cuda:0'})["state_dict"]
    # generator.load_state_dict(cpk, strict=False)
    print("Generator model loaded")

# initialize discriminator    
discriminator = Discriminator()
if discriminatorWeights != '':
    discriminator.load_state_dict(torch.load(join(out,experiment,discriminatorWeights)))
    print("Discriminator model loaded")

# feature extractor and losses
feature_extractor = FeatureExtractor(torchvision.models.vgg19(pretrained=True))
content_criterion = nn.MSELoss()
# content_criterion=SSIM()
adversarial_criterion = nn.BCELoss()

ones_const = Variable(torch.ones(batchSize, 1))

# use GPU if available
if cuda:
    generator.cuda()
    discriminator.cuda()
    feature_extractor.cuda()
    content_criterion.cuda()
    adversarial_criterion.cuda()
    ones_const = ones_const.cuda()

low_res = torch.FloatTensor(batchSize, 3, imageSize_w+ border, imageSize_h + border)

# set the visualizer
# visualizer = Visualizer(image_size=imageSize_w*upSampling)

# optimizers for generator and discriminator
# optim_generator = optim.Adam(generator.parameters(), lr=0.0001)
# optim_discriminator = optim.Adam(discriminator.parameters(), lr=0.0001)
lr=0.0001
optim_generator= optim.Adam(params=filter(lambda p: p.requires_grad, generator.parameters()),lr=lr)

optim_discriminator= optim.Adam(params=filter(lambda p: p.requires_grad, discriminator.parameters()),lr=lr)
# print(generator)


# # summary(generator, (3, imageSize_w + border, imageSize_h + border))
# Out:
# Generator model loaded
# Discriminator model loaded
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# HBox(children=(FloatProgress(value=0.0, max=574673361.0), HTML(value='')))

# %% [markdown]
# Entrenament - Entrenament Model

# %%
print ('Model training\n\n')
vifp=0
stamp=datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
stamp=stamp+"_16parts_defian_mse"
parts=16

for epoch in range(nEpochs):
    print("Epoch: %d" % (epoch+1))
    mean_generator_content_loss = 0.0
    mean_generator_adversarial_loss = 0.0
    mean_generator_total_loss = 0.0
    mean_discriminator_loss = 0.0
    
    mean_ssim = 0.0
    mean_vifp = 0.0
    dataiter=iter(dataloader_train)

    for i, data in enumerate(dataloader_train_real):
        
        sample_fname, _ = dataloader_train_real.dataset.samples[i]
        print(sample_fname)
        head, tail = os.path.split(sample_fname)
        final_tail=tail[12:17]
        print(final_tail)


        # get data
        low_res, _ = dataiter.next()
        low_res=torch.squeeze(low_res)

        high_res_real, _ =  data

        high_res_real=torch.squeeze(high_res_real)
        # print('\r Tamany baixa resolució [%d]',(low_res[0].shape))
        # print('\r Tamany resolució real[%d]',(high_res_real[0].shape))
        mean_ssim_subset=0
        
        
        for j in range(batchSize*parts):

            # low_res[j] = scale(high_res_real[j])
            # low_res[j]=normalize(low_res[j])
            # high_res_real[j] = normalize(high_res_real[j])
            low_res_crop=low_res[j,:,:,:].unsqueeze(0)
            high_res_real_crop = high_res_real[j,:,:,:].unsqueeze(0)

        
        

            # generate real and fake inputs
            if cuda:
                high_res_real_crop = Variable(high_res_real_crop.cuda())
                high_res_fake_crop = generator(Variable(low_res_crop).cuda())
                a=torch.rand(batchSize,1)
                target_real = Variable(a*0.5 + 0.7).cuda()
                b=torch.rand(batchSize,1)
                target_fake = Variable(b*0.3).cuda()
                
            else:
                high_res_real = Variable(high_res_real)
                high_res_fake = generator(Variable(low_res))
                a=torch.rand(batchSize,1)
                target_real = Variable(a*0.5 + 0.7)
                b=torch.rand(batchSize,1)
                target_fake = Variable(b*0.3)
            
            ######### Train discriminator #########
            discriminator.zero_grad()
            
            real_out_d = discriminator(high_res_real_crop)
            fake_out_d = discriminator(Variable(high_res_fake_crop.data))
            
            
            discriminator_loss = adversarial_criterion(torch.sigmoid(real_out_d - fake_out_d.mean(0)).view(real_out_d.size()[0], -1), target_real) + \
                                adversarial_criterion(torch.sigmoid(fake_out_d - real_out_d.mean(0)).view(fake_out_d.size()[0], -1), target_fake)
            mean_discriminator_loss += discriminator_loss.item()
            
            discriminator_loss.backward()
            optim_discriminator.step()

            ######### Train generator #########
            generator.zero_grad()

            real_features = Variable(feature_extractor(high_res_real_crop).data)
            fake_features = feature_extractor(high_res_fake_crop)

            generator_content_loss = content_criterion(high_res_fake_crop, high_res_real_crop)  + 0.006*content_criterion(fake_features, real_features)
            mean_generator_content_loss += generator_content_loss.item()
            
            fake_out_g = discriminator(Variable(high_res_fake_crop.data))
            c=fake_out_g.size()[0]
            generator_adversarial_loss = adversarial_criterion(torch.sigmoid(fake_out_g).view(fake_out_g.size()[0], -1), ones_const)
            mean_generator_adversarial_loss += generator_adversarial_loss.item()

            generator_total_loss = generator_content_loss + 1e-3*generator_adversarial_loss
            mean_generator_total_loss += generator_total_loss.item()
            
            generator_total_loss.backward()
            optim_generator.step()   
            # high_res_real_one=high_res_real[0].unsqueeze(0)
            # high_res_fake_one=high_res_fake[0].unsqueeze(0)
            ssim_val = ssim(high_res_real_crop, high_res_fake_crop)
            mean_ssim += ssim_val.item()
            mean_ssim_subset+= ssim_val.item()
            # vifp = vifp_measure(high_res_real, high_res_fake)
            # mean_vifp += vifp
            
            torch.cuda.empty_cache()

            ######### Status and display #########
            if i%5 == 0 :
            #     print('\n')
              print('\r[%d/%d][%d/%d] Discriminator_Loss: %.4f Generator_Loss (Content/Advers/Total): %.4f/%.4f/%.4f (SSIM / VIFP) = (%.4f / %.4f)' % (epoch + 1, nEpochs, i+1, len(dataloader_train), discriminator_loss.item(), generator_content_loss.item(), generator_adversarial_loss.item(), generator_total_loss.item(), ssim_val, vifp))
            try:
              os.makedirs(join(out,stamp,"save_train"))
            except OSError:
              pass

            
            if j==0:
              image0=transform_to_save(high_res_fake_crop.cpu().data[0]) 
              image0=image0.crop((0, 0, imageSize_w*upSampling, imageSize_h*upSampling))
            elif j==1:
              image1=transform_to_save(high_res_fake_crop.cpu().data[0]) 
              image1=image1.crop((border*upSampling/2,0, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling))
            elif j==2:
              image2=transform_to_save(high_res_fake_crop.cpu().data[0]) 
              image2=image2.crop((0,border*upSampling/2, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))  
              
            elif j==3:
              image3=transform_to_save(high_res_fake_crop.cpu().data[0]) 
              image3=image3.crop((border*upSampling/2,border*upSampling/2, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))  
              
            elif j==4:
              image4=transform_to_save(high_res_fake_crop.cpu().data[0]) 
              image4=image4.crop((border*upSampling/2,0, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling))
            elif j==5:
              image5=transform_to_save(high_res_fake_crop.cpu().data[0]) 
              image5=image5.crop(( border*upSampling,0, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))
            elif j==6:
              image6=transform_to_save(high_res_fake_crop.cpu().data[0]) 
              image6=image6.crop(( border*upSampling/2,border*upSampling/2, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))
            elif j==7:
              image7=transform_to_save(high_res_fake_crop.cpu().data[0]) 
              image7=image7.crop(( border*upSampling,border*upSampling/2, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))

            if j==8:
              image8=transform_to_save(high_res_fake_crop.cpu().data[0]) 
              image8=image8.crop((0, border*upSampling/2, imageSize_w*upSampling++border*upSampling, imageSize_h*upSampling+border*upSampling))
            elif j==9:
              image9=transform_to_save(high_res_fake_crop.cpu().data[0]) 
              image9=image9.crop((border*upSampling/2,border*upSampling/2, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))
            elif j==10:
              image10=transform_to_save(high_res_fake_crop.cpu().data[0]) 
              image10=image10.crop((0,border*upSampling, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))  
              
            elif j==11:
              image11=transform_to_save(high_res_fake_crop.cpu().data[0]) 
              image11=image11.crop((border*upSampling/2,border*upSampling, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))  
              
            elif j==12:
              image12=transform_to_save(high_res_fake_crop.cpu().data[0]) 
              image12=image12.crop((border*upSampling/2,border*upSampling/2, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))
            elif j==13:
              image13=transform_to_save(high_res_fake_crop.cpu().data[0]) 
              image13=image13.crop(( border*upSampling,border*upSampling/2, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))
            elif j==14:
              image14=transform_to_save(high_res_fake_crop.cpu().data[0]) 
              image14=image14.crop(( border*upSampling/2,border*upSampling, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))
            elif j==15:
              image15=transform_to_save(high_res_fake_crop.cpu().data[0]) 
              image15=image15.crop(( border*upSampling,border*upSampling, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))


              dst = Image.new('RGB', (image0.width * 4, image0.height*4))
              dst.paste(image0, (0 * image0.width, 0))
              dst.paste(image1, (1 * image0.width, 0))
              dst.paste(image2, (0 * image0.width, 1 * image0.height))
              dst.paste(image3, (1 * image0.width, 1 * image0.height))
              
              dst.paste(image4, (2 * image0.width, 0))
              dst.paste(image5, (3 * image0.width, 0))
              dst.paste(image6, (2 * image0.width, 1 * image0.height))
              dst.paste(image7, (3 * image0.width, 1 * image0.height))

              dst.paste(image8, (0 * image0.width, 2 * image0.height))
              dst.paste(image9, (1 * image0.width, 2 * image0.height))
              dst.paste(image10, (0 * image0.width, 3 * image0.height))
              dst.paste(image11, (1 * image0.width, 3 * image0.height))
              
              dst.paste(image12, (2 * image0.width, 2 * image0.height))
              dst.paste(image13, (3 * image0.width, 2 * image0.height))
              dst.paste(image14, (2 * image0.width, 3 * image0.height))
              dst.paste(image15, (3 * image0.width, 3 * image0.height))

        print(mean_ssim_subset/parts)
        if (mean_ssim_subset/parts)<0.6:
          print("Save")
          # dst.save(join(out,stamp,"save_train","prova_%d.png" % i,)) 
          dst.save(join(out,stamp,"save_train","prova_%s.png" % final_tail,)) 
          # visualizer.show(low_res_crop, high_res_real_crop.cpu().data, high_res_fake_crop.cpu().data)
                            
        
        # print('\n')
        print('\r[%d/%d][%d/%d] Mean_Discriminator_Loss: %.4f Mean_Generator_Loss (Content/Advers/Total): %.4f/%.4f/%.4f (Mean_SSIM / Mean_VIFP) = (%.4f / %.4f)' % (epoch + 1, nEpochs, i+1, len(dataloader_train), mean_discriminator_loss/len(dataloader_train), mean_generator_content_loss/len(dataloader_train), mean_generator_adversarial_loss/len(dataloader_train), mean_generator_total_loss/len(dataloader_train), mean_ssim/len(dataloader_train), mean_vifp/len(dataloader_train)))

      # Do checkpointing
    try:
      os.makedirs(join(out,stamp,"models"))
    except OSError:
      pass
    if mean_ssim/len(dataloader_train) > 3:
      torch.save(generator.state_dict(), '%s/%s/models/generator_final_ep%d_%.4f.pth' % (out,stamp,epoch+1,mean_ssim/len(dataloader_train)))
      torch.save(discriminator.state_dict(), '%s/%s/models/discriminator_final_ep%d_%.4f.pth' % (out,stamp,epoch+1,mean_ssim/len(dataloader_train)))
    
    print("\n Epoch Ended " + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + "\n")
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# [3/15][831/1000] Discriminator_Loss: 0.8141 Generator_Loss (Content/Advers/Total): 0.0610/0.0000/0.0610 (SSIM / VIFP) = (0.3067 / 0.0000)
# [3/15][831/1000] Discriminator_Loss: 0.7599 Generator_Loss (Content/Advers/Total): 0.0523/0.0000/0.0523 (SSIM / VIFP) = (0.3347 / 0.0000)
# [3/15][831/1000] Discriminator_Loss: 0.4223 Generator_Loss (Content/Advers/Total): 0.0591/0.0000/0.0591 (SSIM / VIFP) = (0.2883 / 0.0000)
# [3/15][831/1000] Discriminator_Loss: 1.1055 Generator_Loss (Content/Advers/Total): 0.0487/0.0000/0.0487 (SSIM / VIFP) = (0.3325 / 0.0000)
# [3/15][831/1000] Discriminator_Loss: 0.3896 Generator_Loss (Content/Advers/Total): 0.0487/0.0000/0.0487 (SSIM / VIFP) = (0.3037 / 0.0000)
# [3/15][831/1000] Discriminator_Loss: 0.7603 Generator_Loss (Content/Advers/Total): 0.0510/0.0000/0.0510 (SSIM / VIFP) = (0.2914 / 0.0000)
# [3/15][831/1000] Discriminator_Loss: 1.0869 Generator_Loss (Content/Advers/Total): 0.0458/0.0000/0.0458 (SSIM / VIFP) = (0.3293 / 0.0000)
# [3/15][831/1000] Discriminator_Loss: 0.3366 Generator_Loss (Content/Advers/Total): 0.0510/0.0000/0.0510 (SSIM / VIFP) = (0.3203 / 0.0000)
# [3/15][831/1000] Discriminator_Loss: 0.7631 Generator_Loss (Content/Advers/Total): 0.0483/0.0000/0.0483 (SSIM / VIFP) = (0.3175 / 0.0000)
# [3/15][831/1000] Discriminator_Loss: 1.0005 Generator_Loss (Content/Advers/Total): 0.0416/0.0000/0.0416 (SSIM / VIFP) = (0.3478 / 0.0000)
# [3/15][831/1000] Discriminator_Loss: 0.4295 Generator_Loss (Content/Advers/Total): 0.0480/0.0000/0.0480 (SSIM / VIFP) = (0.3288 / 0.0000)
# [3/15][831/1000] Discriminator_Loss: 0.4823 Generator_Loss (Content/Advers/Total): 0.0385/0.0000/0.0385 (SSIM / VIFP) = (0.3593 / 0.0000)
# 0.32216984406113625
# Save
# [3/15][831/1000] Mean_Discriminator_Loss: 8.8110 Mean_Generator_Loss (Content/Advers/Total): 0.1101/0.0000/0.1101 (Mean_SSIM / Mean_VIFP) = (11.5883 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1785.png
# _1785
# 0.723222628235817
# [3/15][832/1000] Mean_Discriminator_Loss: 8.8244 Mean_Generator_Loss (Content/Advers/Total): 0.1104/0.0000/0.1104 (Mean_SSIM / Mean_VIFP) = (11.5998 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1786.png
# _1786
# 0.4155512470752001
# Save
# [3/15][833/1000] Mean_Discriminator_Loss: 8.8362 Mean_Generator_Loss (Content/Advers/Total): 0.1110/0.0000/0.1110 (Mean_SSIM / Mean_VIFP) = (11.6065 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1787.png
# _1787
# 0.8209393173456192
# [3/15][834/1000] Mean_Discriminator_Loss: 8.8473 Mean_Generator_Loss (Content/Advers/Total): 0.1111/0.0000/0.1111 (Mean_SSIM / Mean_VIFP) = (11.6196 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1788.png
# _1788
# 0.9307436980307102
# [3/15][835/1000] Mean_Discriminator_Loss: 8.8594 Mean_Generator_Loss (Content/Advers/Total): 0.1113/0.0000/0.1113 (Mean_SSIM / Mean_VIFP) = (11.6345 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1789.png
# _1789
# [3/15][836/1000] Discriminator_Loss: 0.2568 Generator_Loss (Content/Advers/Total): 0.0673/0.0000/0.0673 (SSIM / VIFP) = (0.6785 / 0.0000)
# [3/15][836/1000] Discriminator_Loss: 1.2685 Generator_Loss (Content/Advers/Total): 0.0714/0.0000/0.0714 (SSIM / VIFP) = (0.6795 / 0.0000)
# [3/15][836/1000] Discriminator_Loss: 1.2212 Generator_Loss (Content/Advers/Total): 0.0637/0.0000/0.0637 (SSIM / VIFP) = (0.6916 / 0.0000)
# [3/15][836/1000] Discriminator_Loss: 1.2224 Generator_Loss (Content/Advers/Total): 0.0592/0.0000/0.0592 (SSIM / VIFP) = (0.7344 / 0.0000)
# [3/15][836/1000] Discriminator_Loss: 1.5506 Generator_Loss (Content/Advers/Total): 0.0533/0.0000/0.0533 (SSIM / VIFP) = (0.7107 / 0.0000)
# [3/15][836/1000] Discriminator_Loss: 1.2256 Generator_Loss (Content/Advers/Total): 0.0228/0.0000/0.0228 (SSIM / VIFP) = (0.8328 / 0.0000)
# [3/15][836/1000] Discriminator_Loss: 1.2169 Generator_Loss (Content/Advers/Total): 0.0494/0.0000/0.0494 (SSIM / VIFP) = (0.7408 / 0.0000)
# [3/15][836/1000] Discriminator_Loss: 1.4555 Generator_Loss (Content/Advers/Total): 0.0225/0.0000/0.0225 (SSIM / VIFP) = (0.8298 / 0.0000)
# [3/15][836/1000] Discriminator_Loss: 0.9086 Generator_Loss (Content/Advers/Total): 0.0468/0.0000/0.0468 (SSIM / VIFP) = (0.7466 / 0.0000)
# [3/15][836/1000] Discriminator_Loss: 1.0217 Generator_Loss (Content/Advers/Total): 0.0555/0.0000/0.0555 (SSIM / VIFP) = (0.7264 / 0.0000)
# [3/15][836/1000] Discriminator_Loss: 0.4848 Generator_Loss (Content/Advers/Total): 0.0408/0.0000/0.0408 (SSIM / VIFP) = (0.7367 / 0.0000)
# [3/15][836/1000] Discriminator_Loss: 0.5046 Generator_Loss (Content/Advers/Total): 0.0508/0.0000/0.0508 (SSIM / VIFP) = (0.7149 / 0.0000)
# [3/15][836/1000] Discriminator_Loss: -0.1263 Generator_Loss (Content/Advers/Total): 0.0434/0.0000/0.0434 (SSIM / VIFP) = (0.7713 / 0.0000)
# [3/15][836/1000] Discriminator_Loss: 0.6060 Generator_Loss (Content/Advers/Total): 0.0197/0.0000/0.0197 (SSIM / VIFP) = (0.8520 / 0.0000)
# [3/15][836/1000] Discriminator_Loss: 0.7625 Generator_Loss (Content/Advers/Total): 0.0353/0.0000/0.0353 (SSIM / VIFP) = (0.7580 / 0.0000)
# [3/15][836/1000] Discriminator_Loss: 0.2947 Generator_Loss (Content/Advers/Total): 0.0143/0.0000/0.0143 (SSIM / VIFP) = (0.8504 / 0.0000)
# 0.7534033320844173
# [3/15][836/1000] Mean_Discriminator_Loss: 8.8733 Mean_Generator_Loss (Content/Advers/Total): 0.1120/0.0000/0.1120 (Mean_SSIM / Mean_VIFP) = (11.6466 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1791.png
# _1791
# 0.9189649857580662
# [3/15][837/1000] Mean_Discriminator_Loss: 8.8855 Mean_Generator_Loss (Content/Advers/Total): 0.1121/0.0000/0.1121 (Mean_SSIM / Mean_VIFP) = (11.6613 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1792.png
# _1792
# 0.5023761279881
# Save
# [3/15][838/1000] Mean_Discriminator_Loss: 8.8949 Mean_Generator_Loss (Content/Advers/Total): 0.1133/0.0000/0.1133 (Mean_SSIM / Mean_VIFP) = (11.6693 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1793.png
# _1793
# 0.9081863574683666
# [3/15][839/1000] Mean_Discriminator_Loss: 8.9038 Mean_Generator_Loss (Content/Advers/Total): 0.1134/0.0000/0.1134 (Mean_SSIM / Mean_VIFP) = (11.6838 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1794.png
# _1794
# 0.9501037299633026
# [3/15][840/1000] Mean_Discriminator_Loss: 8.9169 Mean_Generator_Loss (Content/Advers/Total): 0.1135/0.0000/0.1135 (Mean_SSIM / Mean_VIFP) = (11.6990 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1795.png
# _1795
# [3/15][841/1000] Discriminator_Loss: 0.1941 Generator_Loss (Content/Advers/Total): 0.0573/0.0000/0.0573 (SSIM / VIFP) = (0.6254 / 0.0000)
# [3/15][841/1000] Discriminator_Loss: 1.7498 Generator_Loss (Content/Advers/Total): 0.0276/0.0000/0.0276 (SSIM / VIFP) = (0.6770 / 0.0000)
# [3/15][841/1000] Discriminator_Loss: 1.3696 Generator_Loss (Content/Advers/Total): 0.0461/0.0000/0.0461 (SSIM / VIFP) = (0.6722 / 0.0000)
# [3/15][841/1000] Discriminator_Loss: 1.0405 Generator_Loss (Content/Advers/Total): 0.0327/0.0000/0.0327 (SSIM / VIFP) = (0.6615 / 0.0000)
# [3/15][841/1000] Discriminator_Loss: 0.7386 Generator_Loss (Content/Advers/Total): 0.0365/0.0000/0.0365 (SSIM / VIFP) = (0.6586 / 0.0000)
# [3/15][841/1000] Discriminator_Loss: 1.0083 Generator_Loss (Content/Advers/Total): 0.0494/0.0000/0.0494 (SSIM / VIFP) = (0.6625 / 0.0000)
# [3/15][841/1000] Discriminator_Loss: 0.9495 Generator_Loss (Content/Advers/Total): 0.0379/0.0000/0.0379 (SSIM / VIFP) = (0.6349 / 0.0000)
# [3/15][841/1000] Discriminator_Loss: 0.6075 Generator_Loss (Content/Advers/Total): 0.0409/0.0000/0.0409 (SSIM / VIFP) = (0.6750 / 0.0000)
# [3/15][841/1000] Discriminator_Loss: 0.9280 Generator_Loss (Content/Advers/Total): 0.0373/0.0000/0.0373 (SSIM / VIFP) = (0.6889 / 0.0000)
# [3/15][841/1000] Discriminator_Loss: 0.4768 Generator_Loss (Content/Advers/Total): 0.0355/0.0000/0.0355 (SSIM / VIFP) = (0.6367 / 0.0000)
# [3/15][841/1000] Discriminator_Loss: 0.7028 Generator_Loss (Content/Advers/Total): 0.0215/0.0000/0.0215 (SSIM / VIFP) = (0.7656 / 0.0000)
# [3/15][841/1000] Discriminator_Loss: 0.7646 Generator_Loss (Content/Advers/Total): 0.0264/0.0000/0.0264 (SSIM / VIFP) = (0.6904 / 0.0000)
# [3/15][841/1000] Discriminator_Loss: 0.5709 Generator_Loss (Content/Advers/Total): 0.0412/0.0000/0.0412 (SSIM / VIFP) = (0.6434 / 0.0000)
# [3/15][841/1000] Discriminator_Loss: 0.8025 Generator_Loss (Content/Advers/Total): 0.0294/0.0000/0.0294 (SSIM / VIFP) = (0.7189 / 0.0000)
# [3/15][841/1000] Discriminator_Loss: 0.4524 Generator_Loss (Content/Advers/Total): 0.0216/0.0000/0.0216 (SSIM / VIFP) = (0.7350 / 0.0000)
# [3/15][841/1000] Discriminator_Loss: 0.4492 Generator_Loss (Content/Advers/Total): 0.0217/0.0000/0.0217 (SSIM / VIFP) = (0.7432 / 0.0000)
# 0.6805708780884743
# [3/15][841/1000] Mean_Discriminator_Loss: 8.9297 Mean_Generator_Loss (Content/Advers/Total): 0.1140/0.0000/0.1140 (Mean_SSIM / Mean_VIFP) = (11.7099 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1796.png
# _1796
# 0.7502275966107845
# [3/15][842/1000] Mean_Discriminator_Loss: 8.9385 Mean_Generator_Loss (Content/Advers/Total): 0.1143/0.0000/0.1143 (Mean_SSIM / Mean_VIFP) = (11.7219 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1797.png
# _1797
# 0.3938637785613537
# Save
# [3/15][843/1000] Mean_Discriminator_Loss: 8.9505 Mean_Generator_Loss (Content/Advers/Total): 0.1149/0.0000/0.1149 (Mean_SSIM / Mean_VIFP) = (11.7282 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1798.png
# _1798
# 0.6520737186074257
# [3/15][844/1000] Mean_Discriminator_Loss: 8.9625 Mean_Generator_Loss (Content/Advers/Total): 0.1154/0.0000/0.1154 (Mean_SSIM / Mean_VIFP) = (11.7387 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1799.png
# _1799
# 0.8315914385020733
# [3/15][845/1000] Mean_Discriminator_Loss: 8.9718 Mean_Generator_Loss (Content/Advers/Total): 0.1155/0.0000/0.1155 (Mean_SSIM / Mean_VIFP) = (11.7520 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1851.png
# _1851
# [3/15][846/1000] Discriminator_Loss: 0.5966 Generator_Loss (Content/Advers/Total): 0.0023/0.0000/0.0023 (SSIM / VIFP) = (0.8864 / 0.0000)
# [3/15][846/1000] Discriminator_Loss: 0.2183 Generator_Loss (Content/Advers/Total): 0.0035/0.0000/0.0035 (SSIM / VIFP) = (0.8780 / 0.0000)
# [3/15][846/1000] Discriminator_Loss: 0.1802 Generator_Loss (Content/Advers/Total): 0.0033/0.0000/0.0033 (SSIM / VIFP) = (0.8807 / 0.0000)
# [3/15][846/1000] Discriminator_Loss: 0.5321 Generator_Loss (Content/Advers/Total): 0.0070/0.0000/0.0070 (SSIM / VIFP) = (0.8483 / 0.0000)
# [3/15][846/1000] Discriminator_Loss: 0.7862 Generator_Loss (Content/Advers/Total): 0.0041/0.0000/0.0041 (SSIM / VIFP) = (0.8767 / 0.0000)
# [3/15][846/1000] Discriminator_Loss: 0.7015 Generator_Loss (Content/Advers/Total): 0.0035/0.0000/0.0035 (SSIM / VIFP) = (0.8742 / 0.0000)
# [3/15][846/1000] Discriminator_Loss: 1.0250 Generator_Loss (Content/Advers/Total): 0.0064/0.0000/0.0064 (SSIM / VIFP) = (0.8541 / 0.0000)
# [3/15][846/1000] Discriminator_Loss: 0.5288 Generator_Loss (Content/Advers/Total): 0.0046/0.0000/0.0046 (SSIM / VIFP) = (0.8690 / 0.0000)
# [3/15][846/1000] Discriminator_Loss: 0.5100 Generator_Loss (Content/Advers/Total): 0.0038/0.0000/0.0038 (SSIM / VIFP) = (0.8812 / 0.0000)
# [3/15][846/1000] Discriminator_Loss: 1.0786 Generator_Loss (Content/Advers/Total): 0.0068/0.0000/0.0068 (SSIM / VIFP) = (0.8589 / 0.0000)
# [3/15][846/1000] Discriminator_Loss: 0.1561 Generator_Loss (Content/Advers/Total): 0.0022/0.0000/0.0022 (SSIM / VIFP) = (0.8968 / 0.0000)
# [3/15][846/1000] Discriminator_Loss: 0.8255 Generator_Loss (Content/Advers/Total): 0.0028/0.0000/0.0028 (SSIM / VIFP) = (0.8935 / 0.0000)
# [3/15][846/1000] Discriminator_Loss: 1.1676 Generator_Loss (Content/Advers/Total): 0.0076/0.0000/0.0076 (SSIM / VIFP) = (0.8606 / 0.0000)
# [3/15][846/1000] Discriminator_Loss: 0.2689 Generator_Loss (Content/Advers/Total): 0.0050/0.0000/0.0050 (SSIM / VIFP) = (0.8721 / 0.0000)
# [3/15][846/1000] Discriminator_Loss: 0.9416 Generator_Loss (Content/Advers/Total): 0.0032/0.0000/0.0032 (SSIM / VIFP) = (0.8929 / 0.0000)
# [3/15][846/1000] Discriminator_Loss: 0.9798 Generator_Loss (Content/Advers/Total): 0.0032/0.0000/0.0032 (SSIM / VIFP) = (0.8850 / 0.0000)
# 0.8755299746990204
# [3/15][846/1000] Mean_Discriminator_Loss: 8.9823 Mean_Generator_Loss (Content/Advers/Total): 0.1155/0.0000/0.1155 (Mean_SSIM / Mean_VIFP) = (11.7660 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1852.png
# _1852
# 0.7064219191670418
# [3/15][847/1000] Mean_Discriminator_Loss: 8.9920 Mean_Generator_Loss (Content/Advers/Total): 0.1163/0.0000/0.1163 (Mean_SSIM / Mean_VIFP) = (11.7773 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1853.png
# _1853
# 0.8092474155128002
# [3/15][848/1000] Mean_Discriminator_Loss: 9.0027 Mean_Generator_Loss (Content/Advers/Total): 0.1165/0.0000/0.1165 (Mean_SSIM / Mean_VIFP) = (11.7902 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1854.png
# _1854
# 0.6462170481681824
# [3/15][849/1000] Mean_Discriminator_Loss: 9.0156 Mean_Generator_Loss (Content/Advers/Total): 0.1168/0.0000/0.1168 (Mean_SSIM / Mean_VIFP) = (11.8006 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1855.png
# _1855
# 0.896353367716074
# [3/15][850/1000] Mean_Discriminator_Loss: 9.0276 Mean_Generator_Loss (Content/Advers/Total): 0.1170/0.0000/0.1170 (Mean_SSIM / Mean_VIFP) = (11.8149 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1856.png
# _1856
# [3/15][851/1000] Discriminator_Loss: 0.9750 Generator_Loss (Content/Advers/Total): 0.0183/0.0000/0.0183 (SSIM / VIFP) = (0.7972 / 0.0000)
# [3/15][851/1000] Discriminator_Loss: 0.2794 Generator_Loss (Content/Advers/Total): 0.0097/0.0000/0.0097 (SSIM / VIFP) = (0.8691 / 0.0000)
# [3/15][851/1000] Discriminator_Loss: 0.3677 Generator_Loss (Content/Advers/Total): 0.0246/0.0000/0.0246 (SSIM / VIFP) = (0.7756 / 0.0000)
# [3/15][851/1000] Discriminator_Loss: 0.6103 Generator_Loss (Content/Advers/Total): 0.0268/0.0000/0.0268 (SSIM / VIFP) = (0.7595 / 0.0000)
# [3/15][851/1000] Discriminator_Loss: 0.5805 Generator_Loss (Content/Advers/Total): 0.0089/0.0000/0.0089 (SSIM / VIFP) = (0.8785 / 0.0000)
# [3/15][851/1000] Discriminator_Loss: 0.8055 Generator_Loss (Content/Advers/Total): 0.0131/0.0000/0.0131 (SSIM / VIFP) = (0.8451 / 0.0000)
# [3/15][851/1000] Discriminator_Loss: 0.6806 Generator_Loss (Content/Advers/Total): 0.0253/0.0000/0.0253 (SSIM / VIFP) = (0.7577 / 0.0000)
# [3/15][851/1000] Discriminator_Loss: 0.6435 Generator_Loss (Content/Advers/Total): 0.0169/0.0000/0.0169 (SSIM / VIFP) = (0.8211 / 0.0000)
# [3/15][851/1000] Discriminator_Loss: 1.1254 Generator_Loss (Content/Advers/Total): 0.0227/0.0000/0.0227 (SSIM / VIFP) = (0.7382 / 0.0000)
# [3/15][851/1000] Discriminator_Loss: 0.7407 Generator_Loss (Content/Advers/Total): 0.0247/0.0000/0.0247 (SSIM / VIFP) = (0.7374 / 0.0000)
# [3/15][851/1000] Discriminator_Loss: -0.2636 Generator_Loss (Content/Advers/Total): 0.0242/0.0000/0.0242 (SSIM / VIFP) = (0.6948 / 0.0000)
# [3/15][851/1000] Discriminator_Loss: 0.7476 Generator_Loss (Content/Advers/Total): 0.0188/0.0000/0.0188 (SSIM / VIFP) = (0.7453 / 0.0000)
# [3/15][851/1000] Discriminator_Loss: 0.6931 Generator_Loss (Content/Advers/Total): 0.0268/0.0000/0.0268 (SSIM / VIFP) = (0.7205 / 0.0000)
# [3/15][851/1000] Discriminator_Loss: 0.1902 Generator_Loss (Content/Advers/Total): 0.0200/0.0000/0.0200 (SSIM / VIFP) = (0.7374 / 0.0000)
# [3/15][851/1000] Discriminator_Loss: 0.7908 Generator_Loss (Content/Advers/Total): 0.0188/0.0000/0.0188 (SSIM / VIFP) = (0.7525 / 0.0000)
# [3/15][851/1000] Discriminator_Loss: 0.2870 Generator_Loss (Content/Advers/Total): 0.0226/0.0000/0.0226 (SSIM / VIFP) = (0.7034 / 0.0000)
# 0.7708291634917259
# [3/15][851/1000] Mean_Discriminator_Loss: 9.0369 Mean_Generator_Loss (Content/Advers/Total): 0.1173/0.0000/0.1173 (Mean_SSIM / Mean_VIFP) = (11.8273 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1857.png
# _1857
# 0.5006164163351059
# Save
# [3/15][852/1000] Mean_Discriminator_Loss: 9.0473 Mean_Generator_Loss (Content/Advers/Total): 0.1176/0.0000/0.1176 (Mean_SSIM / Mean_VIFP) = (11.8353 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1858.png
# _1858
# 0.693238977342844
# [3/15][853/1000] Mean_Discriminator_Loss: 9.0591 Mean_Generator_Loss (Content/Advers/Total): 0.1180/0.0000/0.1180 (Mean_SSIM / Mean_VIFP) = (11.8464 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1859.png
# _1859
# 0.5740064084529877
# Save
# [3/15][854/1000] Mean_Discriminator_Loss: 9.0703 Mean_Generator_Loss (Content/Advers/Total): 0.1183/0.0000/0.1183 (Mean_SSIM / Mean_VIFP) = (11.8555 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1860.png
# _1860
# 0.7725514620542526
# [3/15][855/1000] Mean_Discriminator_Loss: 9.0799 Mean_Generator_Loss (Content/Advers/Total): 0.1184/0.0000/0.1184 (Mean_SSIM / Mean_VIFP) = (11.8679 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1861.png
# _1861
# [3/15][856/1000] Discriminator_Loss: 0.6936 Generator_Loss (Content/Advers/Total): 0.0011/0.0000/0.0011 (SSIM / VIFP) = (0.9616 / 0.0000)
# [3/15][856/1000] Discriminator_Loss: 0.8055 Generator_Loss (Content/Advers/Total): 0.0028/0.0000/0.0028 (SSIM / VIFP) = (0.9528 / 0.0000)
# [3/15][856/1000] Discriminator_Loss: 0.2636 Generator_Loss (Content/Advers/Total): 0.0005/0.0000/0.0005 (SSIM / VIFP) = (0.9690 / 0.0000)
# [3/15][856/1000] Discriminator_Loss: 0.9250 Generator_Loss (Content/Advers/Total): 0.0031/0.0000/0.0031 (SSIM / VIFP) = (0.9538 / 0.0000)
# [3/15][856/1000] Discriminator_Loss: 1.1046 Generator_Loss (Content/Advers/Total): 0.0049/0.0000/0.0049 (SSIM / VIFP) = (0.9437 / 0.0000)
# [3/15][856/1000] Discriminator_Loss: 0.6253 Generator_Loss (Content/Advers/Total): 0.0056/0.0000/0.0056 (SSIM / VIFP) = (0.9385 / 0.0000)
# [3/15][856/1000] Discriminator_Loss: 0.6181 Generator_Loss (Content/Advers/Total): 0.0046/0.0000/0.0046 (SSIM / VIFP) = (0.9445 / 0.0000)
# [3/15][856/1000] Discriminator_Loss: 0.5755 Generator_Loss (Content/Advers/Total): 0.0051/0.0000/0.0051 (SSIM / VIFP) = (0.9438 / 0.0000)
# [3/15][856/1000] Discriminator_Loss: 1.3134 Generator_Loss (Content/Advers/Total): 0.0019/0.0000/0.0019 (SSIM / VIFP) = (0.9577 / 0.0000)
# [3/15][856/1000] Discriminator_Loss: 0.5315 Generator_Loss (Content/Advers/Total): 0.0038/0.0000/0.0038 (SSIM / VIFP) = (0.9497 / 0.0000)
# [3/15][856/1000] Discriminator_Loss: 0.5153 Generator_Loss (Content/Advers/Total): 0.0041/0.0000/0.0041 (SSIM / VIFP) = (0.9484 / 0.0000)
# [3/15][856/1000] Discriminator_Loss: 0.6646 Generator_Loss (Content/Advers/Total): 0.0054/0.0000/0.0054 (SSIM / VIFP) = (0.9431 / 0.0000)
# [3/15][856/1000] Discriminator_Loss: 0.7670 Generator_Loss (Content/Advers/Total): 0.0022/0.0000/0.0022 (SSIM / VIFP) = (0.9563 / 0.0000)
# [3/15][856/1000] Discriminator_Loss: 0.9942 Generator_Loss (Content/Advers/Total): 0.0029/0.0000/0.0029 (SSIM / VIFP) = (0.9550 / 0.0000)
# [3/15][856/1000] Discriminator_Loss: 0.6196 Generator_Loss (Content/Advers/Total): 0.0030/0.0000/0.0030 (SSIM / VIFP) = (0.9556 / 0.0000)
# [3/15][856/1000] Discriminator_Loss: 1.0221 Generator_Loss (Content/Advers/Total): 0.0021/0.0000/0.0021 (SSIM / VIFP) = (0.9584 / 0.0000)
# 0.9520042985677719
# [3/15][856/1000] Mean_Discriminator_Loss: 9.0919 Mean_Generator_Loss (Content/Advers/Total): 0.1185/0.0000/0.1185 (Mean_SSIM / Mean_VIFP) = (11.8831 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1862.png
# _1862
# 0.9263010807335377
# [3/15][857/1000] Mean_Discriminator_Loss: 9.1037 Mean_Generator_Loss (Content/Advers/Total): 0.1186/0.0000/0.1186 (Mean_SSIM / Mean_VIFP) = (11.8980 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1863.png
# _1863
# 0.4283125102519989
# Save
# [3/15][858/1000] Mean_Discriminator_Loss: 9.1136 Mean_Generator_Loss (Content/Advers/Total): 0.1188/0.0000/0.1188 (Mean_SSIM / Mean_VIFP) = (11.9048 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1864.png
# _1864
# 0.726891677826643
# [3/15][859/1000] Mean_Discriminator_Loss: 9.1250 Mean_Generator_Loss (Content/Advers/Total): 0.1193/0.0000/0.1193 (Mean_SSIM / Mean_VIFP) = (11.9164 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1865.png
# _1865
# 0.6496210470795631
# [3/15][860/1000] Mean_Discriminator_Loss: 9.1362 Mean_Generator_Loss (Content/Advers/Total): 0.1197/0.0000/0.1197 (Mean_SSIM / Mean_VIFP) = (11.9268 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1866.png
# _1866
# [3/15][861/1000] Discriminator_Loss: 1.1638 Generator_Loss (Content/Advers/Total): 0.0023/0.0000/0.0023 (SSIM / VIFP) = (0.9526 / 0.0000)
# [3/15][861/1000] Discriminator_Loss: 0.8773 Generator_Loss (Content/Advers/Total): 0.0029/0.0000/0.0029 (SSIM / VIFP) = (0.9527 / 0.0000)
# [3/15][861/1000] Discriminator_Loss: 0.3238 Generator_Loss (Content/Advers/Total): 0.0014/0.0000/0.0014 (SSIM / VIFP) = (0.9588 / 0.0000)
# [3/15][861/1000] Discriminator_Loss: 0.5868 Generator_Loss (Content/Advers/Total): 0.0018/0.0000/0.0018 (SSIM / VIFP) = (0.9591 / 0.0000)
# [3/15][861/1000] Discriminator_Loss: 1.1525 Generator_Loss (Content/Advers/Total): 0.0028/0.0000/0.0028 (SSIM / VIFP) = (0.9558 / 0.0000)
# [3/15][861/1000] Discriminator_Loss: 0.7910 Generator_Loss (Content/Advers/Total): 0.0019/0.0000/0.0019 (SSIM / VIFP) = (0.9583 / 0.0000)
# [3/15][861/1000] Discriminator_Loss: 1.1620 Generator_Loss (Content/Advers/Total): 0.0014/0.0000/0.0014 (SSIM / VIFP) = (0.9606 / 0.0000)
# [3/15][861/1000] Discriminator_Loss: 0.8786 Generator_Loss (Content/Advers/Total): 0.0015/0.0000/0.0015 (SSIM / VIFP) = (0.9588 / 0.0000)
# [3/15][861/1000] Discriminator_Loss: 0.5890 Generator_Loss (Content/Advers/Total): 0.0006/0.0000/0.0006 (SSIM / VIFP) = (0.9638 / 0.0000)
# [3/15][861/1000] Discriminator_Loss: 0.9132 Generator_Loss (Content/Advers/Total): 0.0019/0.0000/0.0019 (SSIM / VIFP) = (0.9581 / 0.0000)
# [3/15][861/1000] Discriminator_Loss: 0.7319 Generator_Loss (Content/Advers/Total): 0.0008/0.0000/0.0008 (SSIM / VIFP) = (0.9616 / 0.0000)
# [3/15][861/1000] Discriminator_Loss: 1.1028 Generator_Loss (Content/Advers/Total): 0.0019/0.0000/0.0019 (SSIM / VIFP) = (0.9519 / 0.0000)
# [3/15][861/1000] Discriminator_Loss: 0.9729 Generator_Loss (Content/Advers/Total): 0.0018/0.0000/0.0018 (SSIM / VIFP) = (0.9525 / 0.0000)
# [3/15][861/1000] Discriminator_Loss: 0.9541 Generator_Loss (Content/Advers/Total): 0.0013/0.0000/0.0013 (SSIM / VIFP) = (0.9537 / 0.0000)
# [3/15][861/1000] Discriminator_Loss: 0.9662 Generator_Loss (Content/Advers/Total): 0.0025/0.0000/0.0025 (SSIM / VIFP) = (0.9423 / 0.0000)
# [3/15][861/1000] Discriminator_Loss: 0.9003 Generator_Loss (Content/Advers/Total): 0.0020/0.0000/0.0020 (SSIM / VIFP) = (0.9429 / 0.0000)
# 0.9552121683955193
# [3/15][861/1000] Mean_Discriminator_Loss: 9.1502 Mean_Generator_Loss (Content/Advers/Total): 0.1197/0.0000/0.1197 (Mean_SSIM / Mean_VIFP) = (11.9421 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1867.png
# _1867
# 0.8850452229380608
# [3/15][862/1000] Mean_Discriminator_Loss: 9.1604 Mean_Generator_Loss (Content/Advers/Total): 0.1198/0.0000/0.1198 (Mean_SSIM / Mean_VIFP) = (11.9563 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1868.png
# _1868
# 0.6200957521796227
# [3/15][863/1000] Mean_Discriminator_Loss: 9.1701 Mean_Generator_Loss (Content/Advers/Total): 0.1205/0.0000/0.1205 (Mean_SSIM / Mean_VIFP) = (11.9662 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1869.png
# _1869
# 0.8792071752250195
# [3/15][864/1000] Mean_Discriminator_Loss: 9.1800 Mean_Generator_Loss (Content/Advers/Total): 0.1206/0.0000/0.1206 (Mean_SSIM / Mean_VIFP) = (11.9803 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1871.png
# _1871
# 0.7320067472755909
# [3/15][865/1000] Mean_Discriminator_Loss: 9.1898 Mean_Generator_Loss (Content/Advers/Total): 0.1209/0.0000/0.1209 (Mean_SSIM / Mean_VIFP) = (11.9920 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1872.png
# _1872
# [3/15][866/1000] Discriminator_Loss: 1.1680 Generator_Loss (Content/Advers/Total): 0.0028/0.0000/0.0028 (SSIM / VIFP) = (0.9457 / 0.0000)
# [3/15][866/1000] Discriminator_Loss: 0.8679 Generator_Loss (Content/Advers/Total): 0.0029/0.0000/0.0029 (SSIM / VIFP) = (0.9449 / 0.0000)
# [3/15][866/1000] Discriminator_Loss: 0.8410 Generator_Loss (Content/Advers/Total): 0.0034/0.0000/0.0034 (SSIM / VIFP) = (0.9385 / 0.0000)
# [3/15][866/1000] Discriminator_Loss: 0.5704 Generator_Loss (Content/Advers/Total): 0.0051/0.0000/0.0051 (SSIM / VIFP) = (0.9259 / 0.0000)
# [3/15][866/1000] Discriminator_Loss: 0.4872 Generator_Loss (Content/Advers/Total): 0.0028/0.0000/0.0028 (SSIM / VIFP) = (0.9463 / 0.0000)
# [3/15][866/1000] Discriminator_Loss: 0.7896 Generator_Loss (Content/Advers/Total): 0.0018/0.0000/0.0018 (SSIM / VIFP) = (0.9576 / 0.0000)
# [3/15][866/1000] Discriminator_Loss: 1.0731 Generator_Loss (Content/Advers/Total): 0.0047/0.0000/0.0047 (SSIM / VIFP) = (0.9332 / 0.0000)
# [3/15][866/1000] Discriminator_Loss: 1.1355 Generator_Loss (Content/Advers/Total): 0.0016/0.0000/0.0016 (SSIM / VIFP) = (0.9593 / 0.0000)
# [3/15][866/1000] Discriminator_Loss: 1.0019 Generator_Loss (Content/Advers/Total): 0.0022/0.0000/0.0022 (SSIM / VIFP) = (0.9491 / 0.0000)
# [3/15][866/1000] Discriminator_Loss: 0.9167 Generator_Loss (Content/Advers/Total): 0.0054/0.0000/0.0054 (SSIM / VIFP) = (0.9225 / 0.0000)
# [3/15][866/1000] Discriminator_Loss: 0.8873 Generator_Loss (Content/Advers/Total): 0.0015/0.0000/0.0015 (SSIM / VIFP) = (0.9560 / 0.0000)
# [3/15][866/1000] Discriminator_Loss: 0.9324 Generator_Loss (Content/Advers/Total): 0.0043/0.0000/0.0043 (SSIM / VIFP) = (0.9339 / 0.0000)
# [3/15][866/1000] Discriminator_Loss: 1.1461 Generator_Loss (Content/Advers/Total): 0.0051/0.0000/0.0051 (SSIM / VIFP) = (0.9297 / 0.0000)
# [3/15][866/1000] Discriminator_Loss: 1.1094 Generator_Loss (Content/Advers/Total): 0.0020/0.0000/0.0020 (SSIM / VIFP) = (0.9552 / 0.0000)
# [3/15][866/1000] Discriminator_Loss: 0.6329 Generator_Loss (Content/Advers/Total): 0.0054/0.0000/0.0054 (SSIM / VIFP) = (0.9285 / 0.0000)
# [3/15][866/1000] Discriminator_Loss: 0.6685 Generator_Loss (Content/Advers/Total): 0.0024/0.0000/0.0024 (SSIM / VIFP) = (0.9488 / 0.0000)
# 0.9421909973025322
# [3/15][866/1000] Mean_Discriminator_Loss: 9.2041 Mean_Generator_Loss (Content/Advers/Total): 0.1209/0.0000/0.1209 (Mean_SSIM / Mean_VIFP) = (12.0070 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1873.png
# _1873
# 0.9486307241022587
# [3/15][867/1000] Mean_Discriminator_Loss: 9.2131 Mean_Generator_Loss (Content/Advers/Total): 0.1210/0.0000/0.1210 (Mean_SSIM / Mean_VIFP) = (12.0222 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1874.png
# _1874
# 0.8254572041332722
# [3/15][868/1000] Mean_Discriminator_Loss: 9.2232 Mean_Generator_Loss (Content/Advers/Total): 0.1210/0.0000/0.1210 (Mean_SSIM / Mean_VIFP) = (12.0354 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1875.png
# _1875
# 0.9611393064260483
# [3/15][869/1000] Mean_Discriminator_Loss: 9.2324 Mean_Generator_Loss (Content/Advers/Total): 0.1210/0.0000/0.1210 (Mean_SSIM / Mean_VIFP) = (12.0508 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1876.png
# _1876
# 0.9308310076594353
# [3/15][870/1000] Mean_Discriminator_Loss: 9.2434 Mean_Generator_Loss (Content/Advers/Total): 0.1211/0.0000/0.1211 (Mean_SSIM / Mean_VIFP) = (12.0657 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1877.png
# _1877
# [3/15][871/1000] Discriminator_Loss: 0.4371 Generator_Loss (Content/Advers/Total): 0.0018/0.0000/0.0018 (SSIM / VIFP) = (0.9521 / 0.0000)
# [3/15][871/1000] Discriminator_Loss: 0.6803 Generator_Loss (Content/Advers/Total): 0.0042/0.0000/0.0042 (SSIM / VIFP) = (0.9309 / 0.0000)
# [3/15][871/1000] Discriminator_Loss: 0.5853 Generator_Loss (Content/Advers/Total): 0.0020/0.0000/0.0020 (SSIM / VIFP) = (0.9491 / 0.0000)
# [3/15][871/1000] Discriminator_Loss: 0.1421 Generator_Loss (Content/Advers/Total): 0.0042/0.0000/0.0042 (SSIM / VIFP) = (0.9282 / 0.0000)
# [3/15][871/1000] Discriminator_Loss: 1.5307 Generator_Loss (Content/Advers/Total): 0.0037/0.0000/0.0037 (SSIM / VIFP) = (0.9346 / 0.0000)
# [3/15][871/1000] Discriminator_Loss: -0.0452 Generator_Loss (Content/Advers/Total): 0.0013/0.0000/0.0013 (SSIM / VIFP) = (0.9612 / 0.0000)
# [3/15][871/1000] Discriminator_Loss: 1.2971 Generator_Loss (Content/Advers/Total): 0.0037/0.0000/0.0037 (SSIM / VIFP) = (0.9325 / 0.0000)
# [3/15][871/1000] Discriminator_Loss: 1.2792 Generator_Loss (Content/Advers/Total): 0.0015/0.0000/0.0015 (SSIM / VIFP) = (0.9587 / 0.0000)
# [3/15][871/1000] Discriminator_Loss: 1.2750 Generator_Loss (Content/Advers/Total): 0.0015/0.0000/0.0015 (SSIM / VIFP) = (0.9564 / 0.0000)
# [3/15][871/1000] Discriminator_Loss: 1.2151 Generator_Loss (Content/Advers/Total): 0.0041/0.0000/0.0041 (SSIM / VIFP) = (0.9283 / 0.0000)
# [3/15][871/1000] Discriminator_Loss: 0.2281 Generator_Loss (Content/Advers/Total): 0.0021/0.0000/0.0021 (SSIM / VIFP) = (0.9516 / 0.0000)
# [3/15][871/1000] Discriminator_Loss: 0.3215 Generator_Loss (Content/Advers/Total): 0.0036/0.0000/0.0036 (SSIM / VIFP) = (0.9307 / 0.0000)
# [3/15][871/1000] Discriminator_Loss: 0.5352 Generator_Loss (Content/Advers/Total): 0.0033/0.0000/0.0033 (SSIM / VIFP) = (0.9362 / 0.0000)
# [3/15][871/1000] Discriminator_Loss: 0.1990 Generator_Loss (Content/Advers/Total): 0.0011/0.0000/0.0011 (SSIM / VIFP) = (0.9637 / 0.0000)
# [3/15][871/1000] Discriminator_Loss: 0.7860 Generator_Loss (Content/Advers/Total): 0.0035/0.0000/0.0035 (SSIM / VIFP) = (0.9338 / 0.0000)
# [3/15][871/1000] Discriminator_Loss: 1.3118 Generator_Loss (Content/Advers/Total): 0.0013/0.0000/0.0013 (SSIM / VIFP) = (0.9604 / 0.0000)
# 0.944277536123991
# [3/15][871/1000] Mean_Discriminator_Loss: 9.2552 Mean_Generator_Loss (Content/Advers/Total): 0.1212/0.0000/0.1212 (Mean_SSIM / Mean_VIFP) = (12.0808 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1878.png
# _1878
# 0.7848084829747677
# [3/15][872/1000] Mean_Discriminator_Loss: 9.2641 Mean_Generator_Loss (Content/Advers/Total): 0.1213/0.0000/0.1213 (Mean_SSIM / Mean_VIFP) = (12.0934 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1879.png
# _1879
# 0.5363392494618893
# Save
# [3/15][873/1000] Mean_Discriminator_Loss: 9.2739 Mean_Generator_Loss (Content/Advers/Total): 0.1218/0.0000/0.1218 (Mean_SSIM / Mean_VIFP) = (12.1020 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1880.png
# _1880
# 0.9538441747426987
# [3/15][874/1000] Mean_Discriminator_Loss: 9.2828 Mean_Generator_Loss (Content/Advers/Total): 0.1218/0.0000/0.1218 (Mean_SSIM / Mean_VIFP) = (12.1172 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1881.png
# _1881
# 0.6746034361422062
# [3/15][875/1000] Mean_Discriminator_Loss: 9.2948 Mean_Generator_Loss (Content/Advers/Total): 0.1220/0.0000/0.1220 (Mean_SSIM / Mean_VIFP) = (12.1280 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1882.png
# _1882
# [3/15][876/1000] Discriminator_Loss: 0.4125 Generator_Loss (Content/Advers/Total): 0.0079/0.0000/0.0079 (SSIM / VIFP) = (0.5769 / 0.0000)
# [3/15][876/1000] Discriminator_Loss: 0.8734 Generator_Loss (Content/Advers/Total): 0.0108/0.0000/0.0108 (SSIM / VIFP) = (0.5782 / 0.0000)
# [3/15][876/1000] Discriminator_Loss: 1.0384 Generator_Loss (Content/Advers/Total): 0.0079/0.0000/0.0079 (SSIM / VIFP) = (0.5892 / 0.0000)
# [3/15][876/1000] Discriminator_Loss: 0.8956 Generator_Loss (Content/Advers/Total): 0.0082/0.0000/0.0082 (SSIM / VIFP) = (0.6156 / 0.0000)
# [3/15][876/1000] Discriminator_Loss: 1.1026 Generator_Loss (Content/Advers/Total): 0.0099/0.0000/0.0099 (SSIM / VIFP) = (0.5310 / 0.0000)
# [3/15][876/1000] Discriminator_Loss: 0.3863 Generator_Loss (Content/Advers/Total): 0.0071/0.0000/0.0071 (SSIM / VIFP) = (0.5519 / 0.0000)
# [3/15][876/1000] Discriminator_Loss: 0.7108 Generator_Loss (Content/Advers/Total): 0.0090/0.0000/0.0090 (SSIM / VIFP) = (0.5726 / 0.0000)
# [3/15][876/1000] Discriminator_Loss: 0.3383 Generator_Loss (Content/Advers/Total): 0.0098/0.0000/0.0098 (SSIM / VIFP) = (0.5678 / 0.0000)
# [3/15][876/1000] Discriminator_Loss: -0.0303 Generator_Loss (Content/Advers/Total): 0.0136/0.0000/0.0136 (SSIM / VIFP) = (0.5806 / 0.0000)
# [3/15][876/1000] Discriminator_Loss: 0.9635 Generator_Loss (Content/Advers/Total): 0.0162/0.0000/0.0162 (SSIM / VIFP) = (0.6209 / 0.0000)
# [3/15][876/1000] Discriminator_Loss: 0.3982 Generator_Loss (Content/Advers/Total): 0.0155/0.0000/0.0155 (SSIM / VIFP) = (0.5986 / 0.0000)
# [3/15][876/1000] Discriminator_Loss: 0.1616 Generator_Loss (Content/Advers/Total): 0.0133/0.0000/0.0133 (SSIM / VIFP) = (0.6461 / 0.0000)
# [3/15][876/1000] Discriminator_Loss: 1.0984 Generator_Loss (Content/Advers/Total): 0.0172/0.0000/0.0172 (SSIM / VIFP) = (0.6111 / 0.0000)
# [3/15][876/1000] Discriminator_Loss: 0.5668 Generator_Loss (Content/Advers/Total): 0.0165/0.0000/0.0165 (SSIM / VIFP) = (0.6080 / 0.0000)
# [3/15][876/1000] Discriminator_Loss: 0.6421 Generator_Loss (Content/Advers/Total): 0.0165/0.0000/0.0165 (SSIM / VIFP) = (0.6110 / 0.0000)
# [3/15][876/1000] Discriminator_Loss: 1.1921 Generator_Loss (Content/Advers/Total): 0.0180/0.0000/0.0180 (SSIM / VIFP) = (0.5896 / 0.0000)
# 0.5905567333102226
# Save
# [3/15][876/1000] Mean_Discriminator_Loss: 9.3056 Mean_Generator_Loss (Content/Advers/Total): 0.1222/0.0000/0.1222 (Mean_SSIM / Mean_VIFP) = (12.1375 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1883.png
# _1883
# 0.9083678908646107
# [3/15][877/1000] Mean_Discriminator_Loss: 9.3171 Mean_Generator_Loss (Content/Advers/Total): 0.1223/0.0000/0.1223 (Mean_SSIM / Mean_VIFP) = (12.1520 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1884.png
# _1884
# 0.8133761845529079
# [3/15][878/1000] Mean_Discriminator_Loss: 9.3269 Mean_Generator_Loss (Content/Advers/Total): 0.1228/0.0000/0.1228 (Mean_SSIM / Mean_VIFP) = (12.1650 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1885.png
# _1885
# 0.7211973816156387
# [3/15][879/1000] Mean_Discriminator_Loss: 9.3374 Mean_Generator_Loss (Content/Advers/Total): 0.1230/0.0000/0.1230 (Mean_SSIM / Mean_VIFP) = (12.1765 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1886.png
# _1886
# 0.6838484518229961
# [3/15][880/1000] Mean_Discriminator_Loss: 9.3484 Mean_Generator_Loss (Content/Advers/Total): 0.1235/0.0000/0.1235 (Mean_SSIM / Mean_VIFP) = (12.1875 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1887.png
# _1887
# [3/15][881/1000] Discriminator_Loss: 0.9713 Generator_Loss (Content/Advers/Total): 0.0298/0.0000/0.0298 (SSIM / VIFP) = (0.3511 / 0.0000)
# [3/15][881/1000] Discriminator_Loss: 0.9604 Generator_Loss (Content/Advers/Total): 0.0258/0.0000/0.0258 (SSIM / VIFP) = (0.3505 / 0.0000)
# [3/15][881/1000] Discriminator_Loss: 0.9786 Generator_Loss (Content/Advers/Total): 0.0256/0.0000/0.0256 (SSIM / VIFP) = (0.3266 / 0.0000)
# [3/15][881/1000] Discriminator_Loss: 0.3869 Generator_Loss (Content/Advers/Total): 0.0238/0.0000/0.0238 (SSIM / VIFP) = (0.3442 / 0.0000)
# [3/15][881/1000] Discriminator_Loss: 0.8508 Generator_Loss (Content/Advers/Total): 0.0242/0.0000/0.0242 (SSIM / VIFP) = (0.3859 / 0.0000)
# [3/15][881/1000] Discriminator_Loss: 1.1967 Generator_Loss (Content/Advers/Total): 0.0307/0.0000/0.0307 (SSIM / VIFP) = (0.4459 / 0.0000)
# [3/15][881/1000] Discriminator_Loss: 0.8453 Generator_Loss (Content/Advers/Total): 0.0231/0.0000/0.0231 (SSIM / VIFP) = (0.3905 / 0.0000)
# [3/15][881/1000] Discriminator_Loss: 0.8279 Generator_Loss (Content/Advers/Total): 0.0257/0.0000/0.0257 (SSIM / VIFP) = (0.4132 / 0.0000)
# [3/15][881/1000] Discriminator_Loss: 0.4904 Generator_Loss (Content/Advers/Total): 0.0220/0.0000/0.0220 (SSIM / VIFP) = (0.3103 / 0.0000)
# [3/15][881/1000] Discriminator_Loss: 0.7399 Generator_Loss (Content/Advers/Total): 0.0214/0.0000/0.0214 (SSIM / VIFP) = (0.2979 / 0.0000)
# [3/15][881/1000] Discriminator_Loss: 0.5899 Generator_Loss (Content/Advers/Total): 0.0194/0.0000/0.0194 (SSIM / VIFP) = (0.3343 / 0.0000)
# [3/15][881/1000] Discriminator_Loss: 0.2165 Generator_Loss (Content/Advers/Total): 0.0190/0.0000/0.0190 (SSIM / VIFP) = (0.3528 / 0.0000)
# [3/15][881/1000] Discriminator_Loss: 1.1822 Generator_Loss (Content/Advers/Total): 0.0201/0.0000/0.0201 (SSIM / VIFP) = (0.3215 / 0.0000)
# [3/15][881/1000] Discriminator_Loss: 0.8522 Generator_Loss (Content/Advers/Total): 0.0205/0.0000/0.0205 (SSIM / VIFP) = (0.3055 / 0.0000)
# [3/15][881/1000] Discriminator_Loss: 0.6499 Generator_Loss (Content/Advers/Total): 0.0194/0.0000/0.0194 (SSIM / VIFP) = (0.3529 / 0.0000)
# [3/15][881/1000] Discriminator_Loss: 0.7091 Generator_Loss (Content/Advers/Total): 0.0188/0.0000/0.0188 (SSIM / VIFP) = (0.3156 / 0.0000)
# 0.34991914592683315
# Save
# [3/15][881/1000] Mean_Discriminator_Loss: 9.3608 Mean_Generator_Loss (Content/Advers/Total): 0.1239/0.0000/0.1239 (Mean_SSIM / Mean_VIFP) = (12.1931 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1888.png
# _1888
# 0.8906921334564686
# [3/15][882/1000] Mean_Discriminator_Loss: 9.3738 Mean_Generator_Loss (Content/Advers/Total): 0.1239/0.0000/0.1239 (Mean_SSIM / Mean_VIFP) = (12.2073 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1889.png
# _1889
# 0.8012884110212326
# [3/15][883/1000] Mean_Discriminator_Loss: 9.3848 Mean_Generator_Loss (Content/Advers/Total): 0.1242/0.0000/0.1242 (Mean_SSIM / Mean_VIFP) = (12.2202 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1891.png
# _1891
# 0.5570822339504957
# Save
# [3/15][884/1000] Mean_Discriminator_Loss: 9.3942 Mean_Generator_Loss (Content/Advers/Total): 0.1244/0.0000/0.1244 (Mean_SSIM / Mean_VIFP) = (12.2291 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1892.png
# _1892
# 0.8833513148128986
# [3/15][885/1000] Mean_Discriminator_Loss: 9.4042 Mean_Generator_Loss (Content/Advers/Total): 0.1245/0.0000/0.1245 (Mean_SSIM / Mean_VIFP) = (12.2432 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1893.png
# _1893
# [3/15][886/1000] Discriminator_Loss: 1.5839 Generator_Loss (Content/Advers/Total): 0.0124/0.0000/0.0124 (SSIM / VIFP) = (0.4778 / 0.0000)
# [3/15][886/1000] Discriminator_Loss: 1.2702 Generator_Loss (Content/Advers/Total): 0.0148/0.0000/0.0148 (SSIM / VIFP) = (0.5077 / 0.0000)
# [3/15][886/1000] Discriminator_Loss: 0.8755 Generator_Loss (Content/Advers/Total): 0.0124/0.0000/0.0124 (SSIM / VIFP) = (0.4867 / 0.0000)
# [3/15][886/1000] Discriminator_Loss: 1.1581 Generator_Loss (Content/Advers/Total): 0.0131/0.0000/0.0131 (SSIM / VIFP) = (0.5172 / 0.0000)
# [3/15][886/1000] Discriminator_Loss: 0.3209 Generator_Loss (Content/Advers/Total): 0.0108/0.0000/0.0108 (SSIM / VIFP) = (0.5680 / 0.0000)
# [3/15][886/1000] Discriminator_Loss: 0.6221 Generator_Loss (Content/Advers/Total): 0.0088/0.0000/0.0088 (SSIM / VIFP) = (0.5885 / 0.0000)
# [3/15][886/1000] Discriminator_Loss: 0.0920 Generator_Loss (Content/Advers/Total): 0.0116/0.0000/0.0116 (SSIM / VIFP) = (0.5420 / 0.0000)
# [3/15][886/1000] Discriminator_Loss: 1.1025 Generator_Loss (Content/Advers/Total): 0.0104/0.0000/0.0104 (SSIM / VIFP) = (0.5547 / 0.0000)
# [3/15][886/1000] Discriminator_Loss: 0.6930 Generator_Loss (Content/Advers/Total): 0.0207/0.0000/0.0207 (SSIM / VIFP) = (0.4800 / 0.0000)
# [3/15][886/1000] Discriminator_Loss: 0.9370 Generator_Loss (Content/Advers/Total): 0.0198/0.0000/0.0198 (SSIM / VIFP) = (0.4898 / 0.0000)
# [3/15][886/1000] Discriminator_Loss: 0.3761 Generator_Loss (Content/Advers/Total): 0.0148/0.0000/0.0148 (SSIM / VIFP) = (0.5681 / 0.0000)
# [3/15][886/1000] Discriminator_Loss: 0.8319 Generator_Loss (Content/Advers/Total): 0.0131/0.0000/0.0131 (SSIM / VIFP) = (0.5635 / 0.0000)
# [3/15][886/1000] Discriminator_Loss: 0.0928 Generator_Loss (Content/Advers/Total): 0.0121/0.0000/0.0121 (SSIM / VIFP) = (0.5632 / 0.0000)
# [3/15][886/1000] Discriminator_Loss: 0.9702 Generator_Loss (Content/Advers/Total): 0.0111/0.0000/0.0111 (SSIM / VIFP) = (0.5766 / 0.0000)
# [3/15][886/1000] Discriminator_Loss: 0.6172 Generator_Loss (Content/Advers/Total): 0.0093/0.0000/0.0093 (SSIM / VIFP) = (0.6136 / 0.0000)
# [3/15][886/1000] Discriminator_Loss: 0.9701 Generator_Loss (Content/Advers/Total): 0.0087/0.0000/0.0087 (SSIM / VIFP) = (0.6208 / 0.0000)
# 0.5448812730610371
# Save
# [3/15][886/1000] Mean_Discriminator_Loss: 9.4167 Mean_Generator_Loss (Content/Advers/Total): 0.1247/0.0000/0.1247 (Mean_SSIM / Mean_VIFP) = (12.2519 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1894.png
# _1894
# 0.8711953461170197
# [3/15][887/1000] Mean_Discriminator_Loss: 9.4267 Mean_Generator_Loss (Content/Advers/Total): 0.1249/0.0000/0.1249 (Mean_SSIM / Mean_VIFP) = (12.2659 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1895.png
# _1895
# 0.942264799028635
# [3/15][888/1000] Mean_Discriminator_Loss: 9.4395 Mean_Generator_Loss (Content/Advers/Total): 0.1249/0.0000/0.1249 (Mean_SSIM / Mean_VIFP) = (12.2809 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1896.png
# _1896
# 0.5437105242162943
# Save
# [3/15][889/1000] Mean_Discriminator_Loss: 9.4481 Mean_Generator_Loss (Content/Advers/Total): 0.1251/0.0000/0.1251 (Mean_SSIM / Mean_VIFP) = (12.2896 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1897.png
# _1897
# 0.9463178142905235
# [3/15][890/1000] Mean_Discriminator_Loss: 9.4597 Mean_Generator_Loss (Content/Advers/Total): 0.1253/0.0000/0.1253 (Mean_SSIM / Mean_VIFP) = (12.3048 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1898.png
# _1898
# [3/15][891/1000] Discriminator_Loss: 0.2539 Generator_Loss (Content/Advers/Total): 0.0091/0.0000/0.0091 (SSIM / VIFP) = (0.9181 / 0.0000)
# [3/15][891/1000] Discriminator_Loss: 0.9154 Generator_Loss (Content/Advers/Total): 0.0148/0.0000/0.0148 (SSIM / VIFP) = (0.8881 / 0.0000)
# [3/15][891/1000] Discriminator_Loss: 0.3361 Generator_Loss (Content/Advers/Total): 0.0129/0.0000/0.0129 (SSIM / VIFP) = (0.8998 / 0.0000)
# [3/15][891/1000] Discriminator_Loss: 0.7841 Generator_Loss (Content/Advers/Total): 0.0202/0.0000/0.0202 (SSIM / VIFP) = (0.8735 / 0.0000)
# [3/15][891/1000] Discriminator_Loss: 1.3095 Generator_Loss (Content/Advers/Total): 0.0122/0.0000/0.0122 (SSIM / VIFP) = (0.9014 / 0.0000)
# [3/15][891/1000] Discriminator_Loss: 0.3826 Generator_Loss (Content/Advers/Total): 0.0075/0.0000/0.0075 (SSIM / VIFP) = (0.9313 / 0.0000)
# [3/15][891/1000] Discriminator_Loss: 0.8327 Generator_Loss (Content/Advers/Total): 0.0217/0.0000/0.0217 (SSIM / VIFP) = (0.8597 / 0.0000)
# [3/15][891/1000] Discriminator_Loss: 0.7868 Generator_Loss (Content/Advers/Total): 0.0120/0.0000/0.0120 (SSIM / VIFP) = (0.9126 / 0.0000)
# [3/15][891/1000] Discriminator_Loss: 0.8113 Generator_Loss (Content/Advers/Total): 0.0114/0.0000/0.0114 (SSIM / VIFP) = (0.9050 / 0.0000)
# [3/15][891/1000] Discriminator_Loss: 1.3097 Generator_Loss (Content/Advers/Total): 0.0165/0.0000/0.0165 (SSIM / VIFP) = (0.8790 / 0.0000)
# [3/15][891/1000] Discriminator_Loss: 0.6273 Generator_Loss (Content/Advers/Total): 0.0075/0.0000/0.0075 (SSIM / VIFP) = (0.9263 / 0.0000)
# [3/15][891/1000] Discriminator_Loss: 1.0244 Generator_Loss (Content/Advers/Total): 0.0108/0.0000/0.0108 (SSIM / VIFP) = (0.9114 / 0.0000)
# [3/15][891/1000] Discriminator_Loss: 1.0061 Generator_Loss (Content/Advers/Total): 0.0174/0.0000/0.0174 (SSIM / VIFP) = (0.8805 / 0.0000)
# [3/15][891/1000] Discriminator_Loss: 1.2697 Generator_Loss (Content/Advers/Total): 0.0114/0.0000/0.0114 (SSIM / VIFP) = (0.9041 / 0.0000)
# [3/15][891/1000] Discriminator_Loss: 0.5097 Generator_Loss (Content/Advers/Total): 0.0117/0.0000/0.0117 (SSIM / VIFP) = (0.9056 / 0.0000)
# [3/15][891/1000] Discriminator_Loss: 0.7622 Generator_Loss (Content/Advers/Total): 0.0081/0.0000/0.0081 (SSIM / VIFP) = (0.9136 / 0.0000)
# 0.900627251714468
# [3/15][891/1000] Mean_Discriminator_Loss: 9.4726 Mean_Generator_Loss (Content/Advers/Total): 0.1255/0.0000/0.1255 (Mean_SSIM / Mean_VIFP) = (12.3192 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1899.png
# _1899
# 0.8386833220720291
# [3/15][892/1000] Mean_Discriminator_Loss: 9.4837 Mean_Generator_Loss (Content/Advers/Total): 0.1257/0.0000/0.1257 (Mean_SSIM / Mean_VIFP) = (12.3326 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1951.png
# _1951
# 0.9401311092078686
# [3/15][893/1000] Mean_Discriminator_Loss: 9.4913 Mean_Generator_Loss (Content/Advers/Total): 0.1257/0.0000/0.1257 (Mean_SSIM / Mean_VIFP) = (12.3476 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1952.png
# _1952
# 0.48945920355618
# Save
# [3/15][894/1000] Mean_Discriminator_Loss: 9.5002 Mean_Generator_Loss (Content/Advers/Total): 0.1262/0.0000/0.1262 (Mean_SSIM / Mean_VIFP) = (12.3555 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1953.png
# _1953
# 0.4412300977855921
# Save
# [3/15][895/1000] Mean_Discriminator_Loss: 9.5103 Mean_Generator_Loss (Content/Advers/Total): 0.1264/0.0000/0.1264 (Mean_SSIM / Mean_VIFP) = (12.3625 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1954.png
# _1954
# [3/15][896/1000] Discriminator_Loss: 1.1602 Generator_Loss (Content/Advers/Total): 0.0471/0.0000/0.0471 (SSIM / VIFP) = (0.3586 / 0.0000)
# [3/15][896/1000] Discriminator_Loss: 1.0826 Generator_Loss (Content/Advers/Total): 0.0536/0.0000/0.0536 (SSIM / VIFP) = (0.3831 / 0.0000)
# [3/15][896/1000] Discriminator_Loss: 1.0254 Generator_Loss (Content/Advers/Total): 0.0470/0.0000/0.0470 (SSIM / VIFP) = (0.3768 / 0.0000)
# [3/15][896/1000] Discriminator_Loss: 1.0678 Generator_Loss (Content/Advers/Total): 0.0495/0.0000/0.0495 (SSIM / VIFP) = (0.3969 / 0.0000)
# [3/15][896/1000] Discriminator_Loss: 0.8961 Generator_Loss (Content/Advers/Total): 0.0464/0.0000/0.0464 (SSIM / VIFP) = (0.3663 / 0.0000)
# [3/15][896/1000] Discriminator_Loss: 0.2948 Generator_Loss (Content/Advers/Total): 0.0435/0.0000/0.0435 (SSIM / VIFP) = (0.3682 / 0.0000)
# [3/15][896/1000] Discriminator_Loss: 0.5122 Generator_Loss (Content/Advers/Total): 0.0433/0.0000/0.0433 (SSIM / VIFP) = (0.3532 / 0.0000)
# [3/15][896/1000] Discriminator_Loss: 1.4737 Generator_Loss (Content/Advers/Total): 0.0379/0.0000/0.0379 (SSIM / VIFP) = (0.3347 / 0.0000)
# [3/15][896/1000] Discriminator_Loss: 1.0252 Generator_Loss (Content/Advers/Total): 0.0532/0.0000/0.0532 (SSIM / VIFP) = (0.4260 / 0.0000)
# [3/15][896/1000] Discriminator_Loss: 1.0475 Generator_Loss (Content/Advers/Total): 0.0517/0.0000/0.0517 (SSIM / VIFP) = (0.4406 / 0.0000)
# [3/15][896/1000] Discriminator_Loss: 1.1312 Generator_Loss (Content/Advers/Total): 0.0588/0.0000/0.0588 (SSIM / VIFP) = (0.3447 / 0.0000)
# [3/15][896/1000] Discriminator_Loss: 0.6326 Generator_Loss (Content/Advers/Total): 0.0545/0.0000/0.0545 (SSIM / VIFP) = (0.3846 / 0.0000)
# [3/15][896/1000] Discriminator_Loss: 0.7633 Generator_Loss (Content/Advers/Total): 0.0392/0.0000/0.0392 (SSIM / VIFP) = (0.3502 / 0.0000)
# ...
# [4/15][496/1000] Discriminator_Loss: 0.4244 Generator_Loss (Content/Advers/Total): 0.0055/0.0000/0.0055 (SSIM / VIFP) = (0.8401 / 0.0000)
# [4/15][496/1000] Discriminator_Loss: -0.0385 Generator_Loss (Content/Advers/Total): 0.0053/0.0000/0.0053 (SSIM / VIFP) = (0.8459 / 0.0000)
# [4/15][496/1000] Discriminator_Loss: 0.4508 Generator_Loss (Content/Advers/Total): 0.0049/0.0000/0.0049 (SSIM / VIFP) = (0.8499 / 0.0000)
# [4/15][496/1000] Discriminator_Loss: 0.2738 Generator_Loss (Content/Advers/Total): 0.0047/0.0000/0.0047 (SSIM / VIFP) = (0.8543 / 0.0000)
# [4/15][496/1000] Discriminator_Loss: 0.4235 Generator_Loss (Content/Advers/Total): 0.0049/0.0000/0.0049 (SSIM / VIFP) = (0.8562 / 0.0000)
# [4/15][496/1000] Discriminator_Loss: 1.2031 Generator_Loss (Content/Advers/Total): 0.0049/0.0000/0.0049 (SSIM / VIFP) = (0.8573 / 0.0000)
# 0.8476465567946434
# [4/15][496/1000] Mean_Discriminator_Loss: 5.2420 Mean_Generator_Loss (Content/Advers/Total): 0.0326/0.0000/0.0326 (Mean_SSIM / Mean_VIFP) = (7.2908 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1068.png
# _1068
# 0.845499649643898
# [4/15][497/1000] Mean_Discriminator_Loss: 5.2533 Mean_Generator_Loss (Content/Advers/Total): 0.0327/0.0000/0.0327 (Mean_SSIM / Mean_VIFP) = (7.3043 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1069.png
# _1069
# 0.820975948125124
# [4/15][498/1000] Mean_Discriminator_Loss: 5.2632 Mean_Generator_Loss (Content/Advers/Total): 0.0329/0.0000/0.0329 (Mean_SSIM / Mean_VIFP) = (7.3174 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1071.png
# _1071
# 0.876444760710001
# [4/15][499/1000] Mean_Discriminator_Loss: 5.2772 Mean_Generator_Loss (Content/Advers/Total): 0.0331/0.0000/0.0331 (Mean_SSIM / Mean_VIFP) = (7.3314 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1072.png
# _1072
# 0.9028574675321579
# [4/15][500/1000] Mean_Discriminator_Loss: 5.2871 Mean_Generator_Loss (Content/Advers/Total): 0.0332/0.0000/0.0332 (Mean_SSIM / Mean_VIFP) = (7.3459 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1073.png
# _1073
# [4/15][501/1000] Discriminator_Loss: 0.7585 Generator_Loss (Content/Advers/Total): 0.0024/0.0000/0.0024 (SSIM / VIFP) = (0.9399 / 0.0000)
# [4/15][501/1000] Discriminator_Loss: 0.3363 Generator_Loss (Content/Advers/Total): 0.0028/0.0000/0.0028 (SSIM / VIFP) = (0.9398 / 0.0000)
# [4/15][501/1000] Discriminator_Loss: 0.2890 Generator_Loss (Content/Advers/Total): 0.0017/0.0000/0.0017 (SSIM / VIFP) = (0.9528 / 0.0000)
# [4/15][501/1000] Discriminator_Loss: 1.1061 Generator_Loss (Content/Advers/Total): 0.0021/0.0000/0.0021 (SSIM / VIFP) = (0.9498 / 0.0000)
# [4/15][501/1000] Discriminator_Loss: 0.6083 Generator_Loss (Content/Advers/Total): 0.0025/0.0000/0.0025 (SSIM / VIFP) = (0.9431 / 0.0000)
# [4/15][501/1000] Discriminator_Loss: 0.0354 Generator_Loss (Content/Advers/Total): 0.0019/0.0000/0.0019 (SSIM / VIFP) = (0.9485 / 0.0000)
# [4/15][501/1000] Discriminator_Loss: 0.6064 Generator_Loss (Content/Advers/Total): 0.0020/0.0000/0.0020 (SSIM / VIFP) = (0.9456 / 0.0000)
# [4/15][501/1000] Discriminator_Loss: 0.8276 Generator_Loss (Content/Advers/Total): 0.0016/0.0000/0.0016 (SSIM / VIFP) = (0.9517 / 0.0000)
# [4/15][501/1000] Discriminator_Loss: 0.4405 Generator_Loss (Content/Advers/Total): 0.0013/0.0000/0.0013 (SSIM / VIFP) = (0.9585 / 0.0000)
# [4/15][501/1000] Discriminator_Loss: 0.8537 Generator_Loss (Content/Advers/Total): 0.0017/0.0000/0.0017 (SSIM / VIFP) = (0.9533 / 0.0000)
# [4/15][501/1000] Discriminator_Loss: 0.7316 Generator_Loss (Content/Advers/Total): 0.0014/0.0000/0.0014 (SSIM / VIFP) = (0.9581 / 0.0000)
# [4/15][501/1000] Discriminator_Loss: 0.5617 Generator_Loss (Content/Advers/Total): 0.0017/0.0000/0.0017 (SSIM / VIFP) = (0.9555 / 0.0000)
# [4/15][501/1000] Discriminator_Loss: 0.7359 Generator_Loss (Content/Advers/Total): 0.0022/0.0000/0.0022 (SSIM / VIFP) = (0.9466 / 0.0000)
# [4/15][501/1000] Discriminator_Loss: 0.9959 Generator_Loss (Content/Advers/Total): 0.0019/0.0000/0.0019 (SSIM / VIFP) = (0.9513 / 0.0000)
# [4/15][501/1000] Discriminator_Loss: 0.2731 Generator_Loss (Content/Advers/Total): 0.0022/0.0000/0.0022 (SSIM / VIFP) = (0.9529 / 0.0000)
# [4/15][501/1000] Discriminator_Loss: 0.3813 Generator_Loss (Content/Advers/Total): 0.0020/0.0000/0.0020 (SSIM / VIFP) = (0.9528 / 0.0000)
# 0.950013630092144
# [4/15][501/1000] Mean_Discriminator_Loss: 5.2966 Mean_Generator_Loss (Content/Advers/Total): 0.0332/0.0000/0.0332 (Mean_SSIM / Mean_VIFP) = (7.3611 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1074.png
# _1074
# 0.8131102621555328
# [4/15][502/1000] Mean_Discriminator_Loss: 5.3074 Mean_Generator_Loss (Content/Advers/Total): 0.0334/0.0000/0.0334 (Mean_SSIM / Mean_VIFP) = (7.3741 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1075.png
# _1075
# 0.7852134257555008
# [4/15][503/1000] Mean_Discriminator_Loss: 5.3208 Mean_Generator_Loss (Content/Advers/Total): 0.0336/0.0000/0.0336 (Mean_SSIM / Mean_VIFP) = (7.3867 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1076.png
# _1076
# 0.8388622775673866
# [4/15][504/1000] Mean_Discriminator_Loss: 5.3291 Mean_Generator_Loss (Content/Advers/Total): 0.0338/0.0000/0.0338 (Mean_SSIM / Mean_VIFP) = (7.4001 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1077.png
# _1077
# 0.9136460572481155
# [4/15][505/1000] Mean_Discriminator_Loss: 5.3431 Mean_Generator_Loss (Content/Advers/Total): 0.0338/0.0000/0.0338 (Mean_SSIM / Mean_VIFP) = (7.4147 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1078.png
# _1078
# [4/15][506/1000] Discriminator_Loss: 0.6356 Generator_Loss (Content/Advers/Total): 0.0007/0.0000/0.0007 (SSIM / VIFP) = (0.9669 / 0.0000)
# [4/15][506/1000] Discriminator_Loss: 0.7941 Generator_Loss (Content/Advers/Total): 0.0006/0.0000/0.0006 (SSIM / VIFP) = (0.9683 / 0.0000)
# [4/15][506/1000] Discriminator_Loss: 0.2425 Generator_Loss (Content/Advers/Total): 0.0014/0.0000/0.0014 (SSIM / VIFP) = (0.9634 / 0.0000)
# [4/15][506/1000] Discriminator_Loss: 1.0053 Generator_Loss (Content/Advers/Total): 0.0015/0.0000/0.0015 (SSIM / VIFP) = (0.9621 / 0.0000)
# [4/15][506/1000] Discriminator_Loss: 0.8560 Generator_Loss (Content/Advers/Total): 0.0006/0.0000/0.0006 (SSIM / VIFP) = (0.9683 / 0.0000)
# [4/15][506/1000] Discriminator_Loss: 1.0232 Generator_Loss (Content/Advers/Total): 0.0004/0.0000/0.0004 (SSIM / VIFP) = (0.9743 / 0.0000)
# [4/15][506/1000] Discriminator_Loss: 0.5743 Generator_Loss (Content/Advers/Total): 0.0016/0.0000/0.0016 (SSIM / VIFP) = (0.9584 / 0.0000)
# [4/15][506/1000] Discriminator_Loss: 0.6865 Generator_Loss (Content/Advers/Total): 0.0011/0.0000/0.0011 (SSIM / VIFP) = (0.9668 / 0.0000)
# [4/15][506/1000] Discriminator_Loss: 0.7992 Generator_Loss (Content/Advers/Total): 0.0024/0.0000/0.0024 (SSIM / VIFP) = (0.9562 / 0.0000)
# [4/15][506/1000] Discriminator_Loss: 0.3100 Generator_Loss (Content/Advers/Total): 0.0045/0.0000/0.0045 (SSIM / VIFP) = (0.9338 / 0.0000)
# [4/15][506/1000] Discriminator_Loss: 1.1056 Generator_Loss (Content/Advers/Total): 0.0034/0.0000/0.0034 (SSIM / VIFP) = (0.9477 / 0.0000)
# [4/15][506/1000] Discriminator_Loss: 0.5581 Generator_Loss (Content/Advers/Total): 0.0044/0.0000/0.0044 (SSIM / VIFP) = (0.9357 / 0.0000)
# [4/15][506/1000] Discriminator_Loss: 0.9177 Generator_Loss (Content/Advers/Total): 0.0031/0.0000/0.0031 (SSIM / VIFP) = (0.9473 / 0.0000)
# [4/15][506/1000] Discriminator_Loss: 0.8243 Generator_Loss (Content/Advers/Total): 0.0012/0.0000/0.0012 (SSIM / VIFP) = (0.9670 / 0.0000)
# [4/15][506/1000] Discriminator_Loss: 0.4297 Generator_Loss (Content/Advers/Total): 0.0044/0.0000/0.0044 (SSIM / VIFP) = (0.9400 / 0.0000)
# [4/15][506/1000] Discriminator_Loss: 0.8874 Generator_Loss (Content/Advers/Total): 0.0020/0.0000/0.0020 (SSIM / VIFP) = (0.9596 / 0.0000)
# 0.9572333693504333
# [4/15][506/1000] Mean_Discriminator_Loss: 5.3548 Mean_Generator_Loss (Content/Advers/Total): 0.0339/0.0000/0.0339 (Mean_SSIM / Mean_VIFP) = (7.4300 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1079.png
# _1079
# 0.9216198362410069
# [4/15][507/1000] Mean_Discriminator_Loss: 5.3654 Mean_Generator_Loss (Content/Advers/Total): 0.0339/0.0000/0.0339 (Mean_SSIM / Mean_VIFP) = (7.4448 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1080.png
# _1080
# 0.7693086303770542
# [4/15][508/1000] Mean_Discriminator_Loss: 5.3784 Mean_Generator_Loss (Content/Advers/Total): 0.0340/0.0000/0.0340 (Mean_SSIM / Mean_VIFP) = (7.4571 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1081.png
# _1081
# 0.9714722819626331
# [4/15][509/1000] Mean_Discriminator_Loss: 5.3897 Mean_Generator_Loss (Content/Advers/Total): 0.0340/0.0000/0.0340 (Mean_SSIM / Mean_VIFP) = (7.4726 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1082.png
# _1082
# 0.6893863938748837
# [4/15][510/1000] Mean_Discriminator_Loss: 5.3964 Mean_Generator_Loss (Content/Advers/Total): 0.0347/0.0000/0.0347 (Mean_SSIM / Mean_VIFP) = (7.4836 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1083.png
# _1083
# [4/15][511/1000] Discriminator_Loss: 0.8546 Generator_Loss (Content/Advers/Total): 0.0014/0.0000/0.0014 (SSIM / VIFP) = (0.9365 / 0.0000)
# [4/15][511/1000] Discriminator_Loss: 0.2227 Generator_Loss (Content/Advers/Total): 0.0016/0.0000/0.0016 (SSIM / VIFP) = (0.9345 / 0.0000)
# [4/15][511/1000] Discriminator_Loss: 0.8642 Generator_Loss (Content/Advers/Total): 0.0012/0.0000/0.0012 (SSIM / VIFP) = (0.9409 / 0.0000)
# [4/15][511/1000] Discriminator_Loss: 0.3512 Generator_Loss (Content/Advers/Total): 0.0011/0.0000/0.0011 (SSIM / VIFP) = (0.9481 / 0.0000)
# [4/15][511/1000] Discriminator_Loss: 1.0465 Generator_Loss (Content/Advers/Total): 0.0012/0.0000/0.0012 (SSIM / VIFP) = (0.9470 / 0.0000)
# [4/15][511/1000] Discriminator_Loss: 0.2864 Generator_Loss (Content/Advers/Total): 0.0012/0.0000/0.0012 (SSIM / VIFP) = (0.9425 / 0.0000)
# [4/15][511/1000] Discriminator_Loss: 0.3722 Generator_Loss (Content/Advers/Total): 0.0012/0.0000/0.0012 (SSIM / VIFP) = (0.9471 / 0.0000)
# [4/15][511/1000] Discriminator_Loss: 0.4851 Generator_Loss (Content/Advers/Total): 0.0013/0.0000/0.0013 (SSIM / VIFP) = (0.9413 / 0.0000)
# [4/15][511/1000] Discriminator_Loss: 0.2436 Generator_Loss (Content/Advers/Total): 0.0008/0.0000/0.0008 (SSIM / VIFP) = (0.9525 / 0.0000)
# [4/15][511/1000] Discriminator_Loss: 0.7149 Generator_Loss (Content/Advers/Total): 0.0007/0.0000/0.0007 (SSIM / VIFP) = (0.9542 / 0.0000)
# [4/15][511/1000] Discriminator_Loss: 0.1786 Generator_Loss (Content/Advers/Total): 0.0005/0.0000/0.0005 (SSIM / VIFP) = (0.9554 / 0.0000)
# [4/15][511/1000] Discriminator_Loss: 1.2137 Generator_Loss (Content/Advers/Total): 0.0007/0.0000/0.0007 (SSIM / VIFP) = (0.9524 / 0.0000)
# [4/15][511/1000] Discriminator_Loss: 0.5891 Generator_Loss (Content/Advers/Total): 0.0005/0.0000/0.0005 (SSIM / VIFP) = (0.9572 / 0.0000)
# [4/15][511/1000] Discriminator_Loss: 0.9902 Generator_Loss (Content/Advers/Total): 0.0004/0.0000/0.0004 (SSIM / VIFP) = (0.9566 / 0.0000)
# [4/15][511/1000] Discriminator_Loss: 0.0013 Generator_Loss (Content/Advers/Total): 0.0005/0.0000/0.0005 (SSIM / VIFP) = (0.9546 / 0.0000)
# [4/15][511/1000] Discriminator_Loss: -0.0980 Generator_Loss (Content/Advers/Total): 0.0005/0.0000/0.0005 (SSIM / VIFP) = (0.9540 / 0.0000)
# 0.9484258703887463
# [4/15][511/1000] Mean_Discriminator_Loss: 5.4047 Mean_Generator_Loss (Content/Advers/Total): 0.0347/0.0000/0.0347 (Mean_SSIM / Mean_VIFP) = (7.4988 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1084.png
# _1084
# 0.6977030821144581
# [4/15][512/1000] Mean_Discriminator_Loss: 5.4166 Mean_Generator_Loss (Content/Advers/Total): 0.0351/0.0000/0.0351 (Mean_SSIM / Mean_VIFP) = (7.5100 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1085.png
# _1085
# 0.709407489746809
# [4/15][513/1000] Mean_Discriminator_Loss: 5.4264 Mean_Generator_Loss (Content/Advers/Total): 0.0354/0.0000/0.0354 (Mean_SSIM / Mean_VIFP) = (7.5213 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1086.png
# _1086
# 0.7244657799601555
# [4/15][514/1000] Mean_Discriminator_Loss: 5.4383 Mean_Generator_Loss (Content/Advers/Total): 0.0359/0.0000/0.0359 (Mean_SSIM / Mean_VIFP) = (7.5329 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1087.png
# _1087
# 0.7020688652992249
# [4/15][515/1000] Mean_Discriminator_Loss: 5.4488 Mean_Generator_Loss (Content/Advers/Total): 0.0362/0.0000/0.0362 (Mean_SSIM / Mean_VIFP) = (7.5442 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1088.png
# _1088
# [4/15][516/1000] Discriminator_Loss: 1.0458 Generator_Loss (Content/Advers/Total): 0.0005/0.0000/0.0005 (SSIM / VIFP) = (0.9768 / 0.0000)
# [4/15][516/1000] Discriminator_Loss: 0.6700 Generator_Loss (Content/Advers/Total): 0.0002/0.0000/0.0002 (SSIM / VIFP) = (0.9788 / 0.0000)
# [4/15][516/1000] Discriminator_Loss: 1.0115 Generator_Loss (Content/Advers/Total): 0.0004/0.0000/0.0004 (SSIM / VIFP) = (0.9791 / 0.0000)
# [4/15][516/1000] Discriminator_Loss: 0.2434 Generator_Loss (Content/Advers/Total): 0.0003/0.0000/0.0003 (SSIM / VIFP) = (0.9803 / 0.0000)
# [4/15][516/1000] Discriminator_Loss: 0.4424 Generator_Loss (Content/Advers/Total): 0.0002/0.0000/0.0002 (SSIM / VIFP) = (0.9655 / 0.0000)
# [4/15][516/1000] Discriminator_Loss: 0.8026 Generator_Loss (Content/Advers/Total): 0.0002/0.0000/0.0002 (SSIM / VIFP) = (0.9711 / 0.0000)
# [4/15][516/1000] Discriminator_Loss: 0.1796 Generator_Loss (Content/Advers/Total): 0.0003/0.0000/0.0003 (SSIM / VIFP) = (0.9651 / 0.0000)
# [4/15][516/1000] Discriminator_Loss: 0.3411 Generator_Loss (Content/Advers/Total): 0.0002/0.0000/0.0002 (SSIM / VIFP) = (0.9705 / 0.0000)
# [4/15][516/1000] Discriminator_Loss: 0.5700 Generator_Loss (Content/Advers/Total): 0.0005/0.0000/0.0005 (SSIM / VIFP) = (0.9766 / 0.0000)
# [4/15][516/1000] Discriminator_Loss: 0.3298 Generator_Loss (Content/Advers/Total): 0.0002/0.0000/0.0002 (SSIM / VIFP) = (0.9790 / 0.0000)
# [4/15][516/1000] Discriminator_Loss: 0.7410 Generator_Loss (Content/Advers/Total): 0.0003/0.0000/0.0003 (SSIM / VIFP) = (0.9778 / 0.0000)
# [4/15][516/1000] Discriminator_Loss: 0.8029 Generator_Loss (Content/Advers/Total): 0.0002/0.0000/0.0002 (SSIM / VIFP) = (0.9823 / 0.0000)
# [4/15][516/1000] Discriminator_Loss: 0.4670 Generator_Loss (Content/Advers/Total): 0.0003/0.0000/0.0003 (SSIM / VIFP) = (0.9664 / 0.0000)
# [4/15][516/1000] Discriminator_Loss: 0.4908 Generator_Loss (Content/Advers/Total): 0.0002/0.0000/0.0002 (SSIM / VIFP) = (0.9711 / 0.0000)
# [4/15][516/1000] Discriminator_Loss: 0.8493 Generator_Loss (Content/Advers/Total): 0.0003/0.0000/0.0003 (SSIM / VIFP) = (0.9708 / 0.0000)
# [4/15][516/1000] Discriminator_Loss: 0.3731 Generator_Loss (Content/Advers/Total): 0.0002/0.0000/0.0002 (SSIM / VIFP) = (0.9714 / 0.0000)
# 0.9739088825881481
# [4/15][516/1000] Mean_Discriminator_Loss: 5.4582 Mean_Generator_Loss (Content/Advers/Total): 0.0362/0.0000/0.0362 (Mean_SSIM / Mean_VIFP) = (7.5597 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1089.png
# _1089
# 0.8135633319616318
# [4/15][517/1000] Mean_Discriminator_Loss: 5.4677 Mean_Generator_Loss (Content/Advers/Total): 0.0365/0.0000/0.0365 (Mean_SSIM / Mean_VIFP) = (7.5728 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1091.png
# _1091
# 0.7508274167776108
# [4/15][518/1000] Mean_Discriminator_Loss: 5.4784 Mean_Generator_Loss (Content/Advers/Total): 0.0368/0.0000/0.0368 (Mean_SSIM / Mean_VIFP) = (7.5848 / 0.0000)
# ./drive/MyDrive/Datasets/SuperResolution/TrainingSet_Real/Set/2400px/image_2400px_1092.png
# _1092

# %% [markdown]
# Avaluació

# %%
"""
Evaluating the model

"""



generatorWeights = 'DeFiAN_L_x4.pth'
discriminatorWeights = 'discriminator_final_ep9_6.7619.pth'
experiment_test='20210318-090015_16parts_defian_mse/models'
# experiment='20210309-214600_8parts_defian_model/models'
# stamp_test="20210309-214600_8parts_defian_model/models"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


eval_generator= Generator(64, 20,10, nn.ReLU(True),attention=True, scale=[upSampling ])

# generator.to(device)

# Optional DataParallel, not needed for single GPU usage
# generator1 = torch.nn.DataParallel(generator, device_ids=[0]).to(device)
# Or, using default 'device_ids=None'
# generator1= torch.nn.DataParallel(generator).to(device)

if generatorWeights != '':
    # generator.load_state_dict(torch.load(join(out,experiment,generatorWeights)))
    cpk = torch.load((join(out,experiment_test,generatorWeights)), map_location={'cuda:1': 'cuda:0'})["state_dict"]
    eval_generator.load_state_dict(cpk, strict=False)
    print("Generator model loaded")

# load the trained model
# eval_generator = Generator(16, upSampling)
# eval_generator.load_state_dict(torch.load(join(out,experiment,generatorWeights)))
eval_generator.eval()
eval_generator.half() 

dataset = 'TestSet'
dataroot_test = './drive/MyDrive/Datasets/SuperResolution/TestSet'



workers = 1
batchSize = 1
cuda = True


if torch.cuda.is_available() and not cuda:
    print("WARNING: You have a CUDA device! You should probably set the variable 'cuda=True'")

# transform the data   

# Mateixa transformació de dades que en training



# load test data
if dataset == 'TestSet':
    dataset_test = datasets.ImageFolder(root=dataroot_test, transform=transform)
assert dataset

dataloader_test = torch.utils.data.DataLoader(dataset_test, batch_size=batchSize,
                                         shuffle=False, num_workers=int(workers))



print(dataset_test[0][0].shape)
# set the visualizer
visualizer = Visualizer(image_size=imageSize_w*upSampling)

# %%
print("Model evaluation\n\n")



# use GPU if available
if cuda:
    eval_generator.cuda()

low_res = torch.FloatTensor(batchSize, 3, imageSize_w, imageSize_h)  

  
for i, data in enumerate(dataloader_test):
    
    
    # get data
    # high_res_real, _ = data
    low_res, _ = data
    low_res=torch.squeeze(low_res)
    
    sample_fname, _ = dataloader_test.dataset.samples[i]
    print(sample_fname)
    head, tail = os.path.split(sample_fname)
    final_tail=tail[12:16]
    print(final_tail)

    # downsample images to low resolution
    for j in range(batchSize*16):
        low_res_crop=low_res[j,:,:,:].unsqueeze(0)
        
      # Generate real and fake inputs
        if cuda:
            with torch.cuda.amp.autocast():
            # high_res_real = Variable(high_res_real.cuda())
               high_res_fake_crop = eval_generator(Variable(low_res_crop).cuda())
            
        
        else:
            # high_res_real = Variable(high_res_real)
            high_res_fake = eval_generator(Variable(low_res_crop))
            
        # ssim_val = ssim(high_res_real, high_res_fake)
        # mean_ssim += ssim_val
        
        # vifp = vifp_measure(high_res_real, high_res_fake)
        # mean_vifp += vifp
      
        try:
          os.makedirs(join(out,experiment_test,"save_test"))
          time.sleep(3)
          print("Sleep 3 s")
        except OSError:
          pass

        if j==0:
          image0=transform_to_save(high_res_fake_crop.cpu().data[0]) 
          image0=image0.crop((0, 0, imageSize_w*upSampling, imageSize_h*upSampling))
        elif j==1:
          image1=transform_to_save(high_res_fake_crop.cpu().data[0]) 
          image1=image1.crop((border*upSampling/2,0, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling))
        elif j==2:
          image2=transform_to_save(high_res_fake_crop.cpu().data[0]) 
          image2=image2.crop((0,border*upSampling/2, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))  
          
        elif j==3:
          image3=transform_to_save(high_res_fake_crop.cpu().data[0]) 
          image3=image3.crop((border*upSampling/2,border*upSampling/2, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))  
          
        elif j==4:
          image4=transform_to_save(high_res_fake_crop.cpu().data[0]) 
          image4=image4.crop((border*upSampling/2,0, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling))
        elif j==5:
          image5=transform_to_save(high_res_fake_crop.cpu().data[0]) 
          image5=image5.crop(( border*upSampling,0, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))
        elif j==6:
          image6=transform_to_save(high_res_fake_crop.cpu().data[0]) 
          image6=image6.crop(( border*upSampling/2,border*upSampling/2, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))
        elif j==7:
          image7=transform_to_save(high_res_fake_crop.cpu().data[0]) 
          image7=image7.crop(( border*upSampling,border*upSampling/2, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))

        if j==8:
          image8=transform_to_save(high_res_fake_crop.cpu().data[0]) 
          image8=image8.crop((0, border*upSampling/2, imageSize_w*upSampling++border*upSampling, imageSize_h*upSampling+border*upSampling))
        elif j==9:
          image9=transform_to_save(high_res_fake_crop.cpu().data[0]) 
          image9=image9.crop((border*upSampling/2,border*upSampling/2, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))
        elif j==10:
          image10=transform_to_save(high_res_fake_crop.cpu().data[0]) 
          image10=image10.crop((0,border*upSampling, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))  
          
        elif j==11:
          image11=transform_to_save(high_res_fake_crop.cpu().data[0]) 
          image11=image11.crop((border*upSampling/2,border*upSampling, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))  
          
        elif j==12:
          image12=transform_to_save(high_res_fake_crop.cpu().data[0]) 
          image12=image12.crop((border*upSampling/2,border*upSampling/2, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))
        elif j==13:
          image13=transform_to_save(high_res_fake_crop.cpu().data[0]) 
          image13=image13.crop(( border*upSampling,border*upSampling/2, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))
        elif j==14:
          image14=transform_to_save(high_res_fake_crop.cpu().data[0]) 
          image14=image14.crop(( border*upSampling/2,border*upSampling, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))
        elif j==15:
          image15=transform_to_save(high_res_fake_crop.cpu().data[0]) 
          image15=image15.crop(( border*upSampling,border*upSampling, imageSize_w*upSampling+border*upSampling, imageSize_h*upSampling+border*upSampling))


          dst = Image.new('RGB', (image0.width * 4, image0.height*4))
          dst.paste(image0, (0 * image0.width, 0))
          dst.paste(image1, (1 * image0.width, 0))
          dst.paste(image2, (0 * image0.width, 1 * image0.height))
          dst.paste(image3, (1 * image0.width, 1 * image0.height))
          
          dst.paste(image4, (2 * image0.width, 0))
          dst.paste(image5, (3 * image0.width, 0))
          dst.paste(image6, (2 * image0.width, 1 * image0.height))
          dst.paste(image7, (3 * image0.width, 1 * image0.height))

          dst.paste(image8, (0 * image0.width, 2 * image0.height))
          dst.paste(image9, (1 * image0.width, 2 * image0.height))
          dst.paste(image10, (0 * image0.width, 3 * image0.height))
          dst.paste(image11, (1 * image0.width, 3 * image0.height))
          
          dst.paste(image12, (2 * image0.width, 2 * image0.height))
          dst.paste(image13, (3 * image0.width, 2 * image0.height))
          dst.paste(image14, (2 * image0.width, 3 * image0.height))
          dst.paste(image15, (3 * image0.width, 3 * image0.height))


          path_save_test=join(out,experiment_test,"save_test","candidate_%s.png" % final_tail,)
          dst.save(path_save_test) 
          print(path_save_test)

    print('\r[%d/%d] ' % ( i+1, len(dataloader_test)))

    # visualizer.show(low_res, high_res_real.cpu().data, high_res_fake.cpu().data)

print("Evaluation ended")    

    # image=transform_to_save(high_res_fake.cpu().data[0]) 
    # image.save(join(out,stamp,"save","prova_%d.png" % i))
